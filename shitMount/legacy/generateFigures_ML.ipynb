# %%
import numpy as np
import pandas as pd
import tensorflow as tf

import matplotlib.pyplot as plt

import os
import joblib

import preprocess, fit_nn, evaluate

def generate_basis(X):

    X_sq = X ** 2

    return np.concatenate([X, X_sq], axis=1)
                          
VA_type = "GMWB"
lapse_type = "nolapse"

cwd = f"../sim_VA/result/{VA_type}/{lapse_type}/"
save_path = f"./trainedModels/{VA_type}_PY/{lapse_type}/"

if not os.path.exists(save_path):
    os.makedirs(save_path)

price = np.load(cwd + f"outerScenarios_{VA_type}_RS_{lapse_type}.npy")
rtn = (price[:, 1:] - price[:, :-1]) / price[:, :-1]
loss_T = np.load(cwd + f"hedgingLoss_{VA_type}_RS_10000_{lapse_type}.npy")

substring_SNS = f"hedgingLoss_{VA_type}_RS_1000_{lapse_type}"

substring_lowNoise = f"hedgingLoss_{VA_type}_RS_100_{lapse_type}"
substring_mediumNoise = f"hedgingLoss_{VA_type}_RS_010_{lapse_type}"
substring_highNoise = f"hedgingLoss_{VA_type}_RS_001_{lapse_type}"

lossFiles_SNS = [file for file in os.listdir(cwd) if substring_SNS in file and os.path.isfile(os.path.join(cwd, file))]

lossFiles_lowNoise = [file for file in os.listdir(cwd) if substring_lowNoise in file and os.path.isfile(os.path.join(cwd, file))]
lossFiles_mediumNoise = [file for file in os.listdir(cwd) if substring_mediumNoise in file and os.path.isfile(os.path.join(cwd, file))]
lossFiles_highNoise = [file for file in os.listdir(cwd) if substring_highNoise in file and os.path.isfile(os.path.join(cwd, file))]

n_rep = 100
test_size = 3000
seed = 22

alpha = 0.05

model_name = "LSTM_LoCap_LowNoise"

MSE_train = np.zeros(n_rep)
MSE_test = np.zeros(n_rep)
MSE_true = np.zeros(n_rep)
VaR = np.zeros(n_rep)
CVaR = np.zeros(n_rep)

for n in range(n_rep):
    
    print("Macro replication:", n + 1)

    loss_LN = np.load(cwd + lossFiles_lowNoise[n % 50])
    
    X_train, y_train, X_test, y_test, y_mean, y_std = preprocess.transform_data(rtn, loss_LN, True, test_size, seed, model="RNN")
    
    X_true, y_true = preprocess.transform_data(rtn, loss_T, training=False, y_mean=y_mean, y_std=y_std, model="RNN")
    
    y_true = np.array(y_true).flatten()

    if "REG" in model_name:
            
        X_train_Q, X_test_Q = generate_basis(X_train), generate_basis(X_test)
        X_true_Q = generate_basis(X_true)

        model = joblib.load(save_path + f"{model_name}_{n}/reg_Q.pkl")

        y_hat_train = model.predict(X_train_Q).flatten()
        y_hat_test = model.predict(X_test_Q).flatten()
        y_hat = model.predict(X_true_Q).flatten()

    else:
        model = tf.keras.models.load_model(save_path + f"{model_name}_{n}/trained_model")

        y_hat_train = model.predict(X_train).flatten()
        y_hat_test = model.predict(X_test).flatten()
        y_hat = model.predict(X_true).flatten()
    
    # Calculating MSE
    MSE_train[n] = np.mean((y_hat_train - y_train)**2)
    MSE_test[n] = np.mean((y_hat_test - y_test)**2)
    MSE_true[n] = np.mean((y_hat - y_true)**2)

    loss_hat = y_hat * y_std + y_mean
    
    q = np.sort(loss_hat)[-int(alpha * len(loss_hat))]
    
    VaR[n] = q
    CVaR[n] = np.mean(loss_hat[loss_hat > q])
    
    np.save(save_path + f"{model_name}_{n}", loss_hat)
# Out:
# Macro replication: 1
# Data is split, training and test data has shape:
# (47000, 240, 1) (47000,) (3000, 240, 1) (3000,)
# 1469/1469 [==============================] - 14s 9ms/step
# 94/94 [==============================] - 1s 9ms/step
# 1563/1563 [==============================] - 14s 9ms/step
# Macro replication: 2
# Data is split, training and test data has shape:
# (47000, 240, 1) (47000,) (3000, 240, 1) (3000,)
# 1469/1469 [==============================] - 13s 9ms/step
# 94/94 [==============================] - 1s 9ms/step
# 1563/1563 [==============================] - 14s 9ms/step
# Macro replication: 3
# Data is split, training and test data has shape:
# (47000, 240, 1) (47000,) (3000, 240, 1) (3000,)
# 1469/1469 [==============================] - 13s 9ms/step
# 94/94 [==============================] - 1s 9ms/step
# 1563/1563 [==============================] - 13s 9ms/step
# Macro replication: 4
# Data is split, training and test data has shape:
# (47000, 240, 1) (47000,) (3000, 240, 1) (3000,)
# 1469/1469 [==============================] - 14s 9ms/step
# 94/94 [==============================] - 1s 10ms/step
# 1563/1563 [==============================] - 14s 9ms/step
# Macro replication: 5
# Data is split, training and test data has shape:
# (47000, 240, 1) (47000,) (3000, 240, 1) (3000,)
# 1469/1469 [==============================] - 14s 9ms/step
# 94/94 [==============================] - 1s 9ms/step
# 1563/1563 [==============================] - 14s 9ms/step
# Macro replication: 6
# Data is split, training and test data has shape:
# (47000, 240, 1) (47000,) (3000, 240, 1) (3000,)
# 1469/1469 [==============================] - 14s 9ms/step
# 94/94 [==============================] - 1s 10ms/step
# 1563/1563 [==============================] - 14s 9ms/step
# Macro replication: 7
# Data is split, training and test data has shape:
# (47000, 240, 1) (47000,) (3000, 240, 1) (3000,)
# 1469/1469 [==============================] - 14s 9ms/step
# 94/94 [==============================] - 1s 9ms/step
# 1563/1563 [==============================] - 14s 9ms/step
# Macro replication: 8
# Data is split, training and test data has shape:
# (47000, 240, 1) (47000,) (3000, 240, 1) (3000,)
# 1469/1469 [==============================] - 14s 9ms/step
# 94/94 [==============================] - 1s 8ms/step
# 1563/1563 [==============================] - 14s 9ms/step
# Macro replication: 9
# Data is split, training and test data has shape:
# (47000, 240, 1) (47000,) (3000, 240, 1) (3000,)
# 1469/1469 [==============================] - 13s 9ms/step
# 94/94 [==============================] - 1s 8ms/step
# 1563/1563 [==============================] - 13s 8ms/step
# Macro replication: 10
# Data is split, training and test data has shape:
# (47000, 240, 1) (47000,) (3000, 240, 1) (3000,)
# 1469/1469 [==============================] - 14s 9ms/step
# 94/94 [==============================] - 1s 8ms/step
# 1563/1563 [==============================] - 13s 8ms/step
# Macro replication: 11
# Data is split, training and test data has shape:
# (47000, 240, 1) (47000,) (3000, 240, 1) (3000,)
# 1469/1469 [==============================] - 13s 9ms/step
# 94/94 [==============================] - 1s 8ms/step
# 1563/1563 [==============================] - 13s 8ms/step
# Macro replication: 12
# Data is split, training and test data has shape:
# (47000, 240, 1) (47000,) (3000, 240, 1) (3000,)
# 1469/1469 [==============================] - 13s 9ms/step
# 94/94 [==============================] - 1s 8ms/step
# 1563/1563 [==============================] - 13s 8ms/step
# Macro replication: 13
# Data is split, training and test data has shape:
# (47000, 240, 1) (47000,) (3000, 240, 1) (3000,)
# 1469/1469 [==============================] - 13s 9ms/step
# 94/94 [==============================] - 1s 8ms/step
# 1563/1563 [==============================] - 13s 8ms/step
# Macro replication: 14
# Data is split, training and test data has shape:
# (47000, 240, 1) (47000,) (3000, 240, 1) (3000,)
# 1469/1469 [==============================] - 13s 9ms/step
# 94/94 [==============================] - 1s 8ms/step
# 1563/1563 [==============================] - 13s 8ms/step
# Macro replication: 15
# Data is split, training and test data has shape:
# (47000, 240, 1) (47000,) (3000, 240, 1) (3000,)
# 1469/1469 [==============================] - 14s 9ms/step
# 94/94 [==============================] - 1s 8ms/step
# 1563/1563 [==============================] - 13s 8ms/step
# Macro replication: 16
# Data is split, training and test data has shape:
# (47000, 240, 1) (47000,) (3000, 240, 1) (3000,)
# 1469/1469 [==============================] - 13s 9ms/step
# 94/94 [==============================] - 1s 8ms/step
# 1563/1563 [==============================] - 13s 8ms/step
# Macro replication: 17
# Data is split, training and test data has shape:
# (47000, 240, 1) (47000,) (3000, 240, 1) (3000,)
# 1469/1469 [==============================] - 13s 9ms/step
# 94/94 [==============================] - 1s 8ms/step
# 1563/1563 [==============================] - 13s 8ms/step
# Macro replication: 18
# Data is split, training and test data has shape:
# (47000, 240, 1) (47000,) (3000, 240, 1) (3000,)
# 1469/1469 [==============================] - 13s 9ms/step
# 94/94 [==============================] - 1s 8ms/step
# 1563/1563 [==============================] - 13s 8ms/step
# Macro replication: 19
# Data is split, training and test data has shape:
# (47000, 240, 1) (47000,) (3000, 240, 1) (3000,)
# 1469/1469 [==============================] - 13s 9ms/step
# 94/94 [==============================] - 1s 8ms/step
# 1563/1563 [==============================] - 13s 8ms/step
# Macro replication: 20
# Data is split, training and test data has shape:
# (47000, 240, 1) (47000,) (3000, 240, 1) (3000,)
# 1469/1469 [==============================] - 13s 9ms/step
# 94/94 [==============================] - 1s 9ms/step
# 1563/1563 [==============================] - 13s 8ms/step
# Macro replication: 21
# Data is split, training and test data has shape:
# (47000, 240, 1) (47000,) (3000, 240, 1) (3000,)
# 1469/1469 [==============================] - 13s 9ms/step
# 94/94 [==============================] - 1s 8ms/step
# 1563/1563 [==============================] - 13s 8ms/step
# Macro replication: 22
# Data is split, training and test data has shape:
# (47000, 240, 1) (47000,) (3000, 240, 1) (3000,)
# 1469/1469 [==============================] - 13s 9ms/step
# 94/94 [==============================] - 1s 8ms/step
# 1563/1563 [==============================] - 13s 8ms/step
# Macro replication: 23
# Data is split, training and test data has shape:
# (47000, 240, 1) (47000,) (3000, 240, 1) (3000,)
# 1469/1469 [==============================] - 13s 9ms/step
# 94/94 [==============================] - 1s 8ms/step
# 1563/1563 [==============================] - 13s 8ms/step
# Macro replication: 24
# Data is split, training and test data has shape:
# (47000, 240, 1) (47000,) (3000, 240, 1) (3000,)
# 1469/1469 [==============================] - 13s 9ms/step
# 94/94 [==============================] - 1s 8ms/step
# 1563/1563 [==============================] - 13s 8ms/step
# Macro replication: 25
# Data is split, training and test data has shape:
# (47000, 240, 1) (47000,) (3000, 240, 1) (3000,)
# 1469/1469 [==============================] - 13s 9ms/step
# 94/94 [==============================] - 1s 8ms/step
# 1563/1563 [==============================] - 13s 8ms/step
# Macro replication: 26
# Data is split, training and test data has shape:
# (47000, 240, 1) (47000,) (3000, 240, 1) (3000,)
# 1469/1469 [==============================] - 13s 9ms/step
# 94/94 [==============================] - 1s 8ms/step
# 1563/1563 [==============================] - 13s 8ms/step
# Macro replication: 27
# Data is split, training and test data has shape:
# (47000, 240, 1) (47000,) (3000, 240, 1) (3000,)
# 1469/1469 [==============================] - 14s 9ms/step
# 94/94 [==============================] - 1s 8ms/step
# 1563/1563 [==============================] - 13s 8ms/step
# Macro replication: 28
# Data is split, training and test data has shape:
# (47000, 240, 1) (47000,) (3000, 240, 1) (3000,)
# 1469/1469 [==============================] - 13s 8ms/step
# 94/94 [==============================] - 1s 8ms/step
# 1563/1563 [==============================] - 13s 8ms/step
# Macro replication: 29
# Data is split, training and test data has shape:
# (47000, 240, 1) (47000,) (3000, 240, 1) (3000,)
# 1469/1469 [==============================] - 13s 9ms/step
# 94/94 [==============================] - 1s 8ms/step
# 1563/1563 [==============================] - 13s 8ms/step
# Macro replication: 30
# Data is split, training and test data has shape:
# (47000, 240, 1) (47000,) (3000, 240, 1) (3000,)
# 1469/1469 [==============================] - 13s 9ms/step
# 94/94 [==============================] - 1s 8ms/step
# 1563/1563 [==============================] - 13s 8ms/step
# Macro replication: 31
# Data is split, training and test data has shape:
# (47000, 240, 1) (47000,) (3000, 240, 1) (3000,)
# 1469/1469 [==============================] - 13s 9ms/step
# 94/94 [==============================] - 1s 8ms/step
# 1563/1563 [==============================] - 13s 8ms/step
# Macro replication: 32
# Data is split, training and test data has shape:
# (47000, 240, 1) (47000,) (3000, 240, 1) (3000,)
# 1469/1469 [==============================] - 13s 8ms/step
# 94/94 [==============================] - 1s 8ms/step
# 1563/1563 [==============================] - 13s 8ms/step
# Macro replication: 33
# Data is split, training and test data has shape:
# (47000, 240, 1) (47000,) (3000, 240, 1) (3000,)
# 1469/1469 [==============================] - 13s 8ms/step
# 94/94 [==============================] - 1s 9ms/step
# 1563/1563 [==============================] - 13s 8ms/step
# Macro replication: 34
# Data is split, training and test data has shape:
# (47000, 240, 1) (47000,) (3000, 240, 1) (3000,)
# 1469/1469 [==============================] - 13s 9ms/step
# 94/94 [==============================] - 1s 9ms/step
# 1563/1563 [==============================] - 13s 8ms/step
# Macro replication: 35
# Data is split, training and test data has shape:
# (47000, 240, 1) (47000,) (3000, 240, 1) (3000,)
# 1469/1469 [==============================] - 13s 9ms/step
# 94/94 [==============================] - 1s 9ms/step
# 1563/1563 [==============================] - 13s 8ms/step
# Macro replication: 36
# Data is split, training and test data has shape:
# (47000, 240, 1) (47000,) (3000, 240, 1) (3000,)
# 1469/1469 [==============================] - 13s 9ms/step
# 94/94 [==============================] - 1s 9ms/step
# 1563/1563 [==============================] - 13s 8ms/step
# Macro replication: 37
# Data is split, training and test data has shape:
# (47000, 240, 1) (47000,) (3000, 240, 1) (3000,)
# 1469/1469 [==============================] - 13s 9ms/step
# 94/94 [==============================] - 1s 8ms/step
# 1563/1563 [==============================] - 13s 8ms/step
# Macro replication: 38
# Data is split, training and test data has shape:
# (47000, 240, 1) (47000,) (3000, 240, 1) (3000,)
# 1469/1469 [==============================] - 13s 9ms/step
# 94/94 [==============================] - 1s 8ms/step
# 1563/1563 [==============================] - 13s 8ms/step
# Macro replication: 39
# Data is split, training and test data has shape:
# (47000, 240, 1) (47000,) (3000, 240, 1) (3000,)
# 1469/1469 [==============================] - 13s 9ms/step
# 94/94 [==============================] - 1s 8ms/step
# 1563/1563 [==============================] - 13s 8ms/step
# Macro replication: 40
# Data is split, training and test data has shape:
# (47000, 240, 1) (47000,) (3000, 240, 1) (3000,)
# 1469/1469 [==============================] - 13s 9ms/step
# 94/94 [==============================] - 1s 8ms/step
# 1563/1563 [==============================] - 13s 8ms/step
# Macro replication: 41
# Data is split, training and test data has shape:
# (47000, 240, 1) (47000,) (3000, 240, 1) (3000,)
# 1469/1469 [==============================] - 13s 9ms/step
# 94/94 [==============================] - 1s 8ms/step
# 1563/1563 [==============================] - 13s 8ms/step
# Macro replication: 42
# Data is split, training and test data has shape:
# (47000, 240, 1) (47000,) (3000, 240, 1) (3000,)
# 1469/1469 [==============================] - 13s 9ms/step
# 94/94 [==============================] - 1s 8ms/step
# 1563/1563 [==============================] - 13s 8ms/step
# Macro replication: 43
# Data is split, training and test data has shape:
# (47000, 240, 1) (47000,) (3000, 240, 1) (3000,)
# 1469/1469 [==============================] - 14s 9ms/step
# 94/94 [==============================] - 1s 8ms/step
# 1563/1563 [==============================] - 13s 8ms/step
# Macro replication: 44
# Data is split, training and test data has shape:
# (47000, 240, 1) (47000,) (3000, 240, 1) (3000,)
# 1469/1469 [==============================] - 13s 9ms/step
# 94/94 [==============================] - 1s 8ms/step
# 1563/1563 [==============================] - 13s 8ms/step
# Macro replication: 45
# Data is split, training and test data has shape:
# (47000, 240, 1) (47000,) (3000, 240, 1) (3000,)
# 1469/1469 [==============================] - 13s 9ms/step
# 94/94 [==============================] - 1s 8ms/step
# 1563/1563 [==============================] - 13s 8ms/step
# Macro replication: 46
# Data is split, training and test data has shape:
# (47000, 240, 1) (47000,) (3000, 240, 1) (3000,)
# 1469/1469 [==============================] - 13s 9ms/step
# 94/94 [==============================] - 1s 8ms/step
# 1563/1563 [==============================] - 13s 8ms/step
# Macro replication: 47
# Data is split, training and test data has shape:
# (47000, 240, 1) (47000,) (3000, 240, 1) (3000,)
# 1469/1469 [==============================] - 13s 9ms/step
# 94/94 [==============================] - 1s 9ms/step
# 1563/1563 [==============================] - 13s 8ms/step
# Macro replication: 48
# Data is split, training and test data has shape:
# (47000, 240, 1) (47000,) (3000, 240, 1) (3000,)
# 1469/1469 [==============================] - 13s 9ms/step
# 94/94 [==============================] - 1s 8ms/step
# 1563/1563 [==============================] - 13s 8ms/step
# Macro replication: 49
# Data is split, training and test data has shape:
# (47000, 240, 1) (47000,) (3000, 240, 1) (3000,)
# 1469/1469 [==============================] - 13s 8ms/step
# 94/94 [==============================] - 1s 8ms/step
# 1563/1563 [==============================] - 13s 8ms/step
# Macro replication: 50
# Data is split, training and test data has shape:
# (47000, 240, 1) (47000,) (3000, 240, 1) (3000,)
# 1469/1469 [==============================] - 13s 9ms/step
# 94/94 [==============================] - 1s 8ms/step
# 1563/1563 [==============================] - 13s 8ms/step

# %%
np.save(save_path + f"{model_name}_CVaR", CVaR)
np.save(save_path + f"{model_name}_VaR", VaR)

# %%
model_name = "LSTM_LoCap_mediumNoise"

MSE_train = np.zeros(n_rep)
MSE_test = np.zeros(n_rep)
MSE_true = np.zeros(n_rep)
VaR = np.zeros(n_rep)
CVaR = np.zeros(n_rep)
VaR_sns = np.zeros(n_rep)
CVaR_sns = np.zeros(n_rep)

for n in range(n_rep):
    
    print("Macro replication:", n + 1)

    loss_sns = np.load(cwd + lossFiles_mediumNoise[n])
    
    X_train, y_train, X_test, y_test, y_mean, y_std = preprocess.transform_data(rtn, loss_LN, True, test_size, seed, model="RNN")
    
    X_true, y_true = preprocess.transform_data(rtn, loss_T, training=False, y_mean=y_mean, y_std=y_std, model="RNN")
    
    y_true = np.array(y_true).flatten()

    if "REG" in model_name:
            
        X_train_Q, X_test_Q = generate_basis(X_train), generate_basis(X_test)
        X_true_Q = generate_basis(X_true)

        model = joblib.load(save_path + f"{model_name}_{n}/reg_Q.pkl")

        y_hat_train = model.predict(X_train_Q).flatten()
        y_hat_test = model.predict(X_test_Q).flatten()
        y_hat = model.predict(X_true_Q).flatten()

    else:
        model = tf.keras.models.load_model(save_path + f"{model_name}_{n}/trained_model")

        y_hat_train = model.predict(X_train).flatten()
        y_hat_test = model.predict(X_test).flatten()
        y_hat = model.predict(X_true).flatten()
    
    # Calculating MSE
    MSE_train[n] = np.mean((y_hat_train - y_train)**2)
    MSE_test[n] = np.mean((y_hat_test - y_test)**2)
    MSE_true[n] = np.mean((y_hat - y_true)**2)

    loss_hat = y_hat * y_std + y_mean
    
    q = np.sort(loss_hat)[-int(alpha * len(loss_hat))]
    
    VaR[n] = q
    CVaR[n] = np.mean(loss_hat[loss_hat > q])
    
    q = np.sort(loss_sns)[-int(alpha * len(loss_hat))]
    
    VaR_sns[n] = q
    CVaR_sns[n] = np.mean(loss_sns[loss_sns > q])
    
    np.save(save_path + f"{model_name}_{n}", loss_hat)
    
np.save(save_path + f"{model_name}_CVaR", CVaR)
np.save(save_path + f"{model_name}_VaR", VaR)
# Out:
# Macro replication: 1
# Data is split, training and test data has shape:
# (47000, 240, 1) (47000,) (3000, 240, 1) (3000,)
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[33], line 37
#      34 else:
#      35     model = tf.keras.models.load_model(save_path + f"{model_name}_{n}/trained_model")
# ---> 37     y_hat_train = model.predict(X_train).flatten()
#      38     y_hat_test = model.predict(X_test).flatten()
#      39     y_hat = model.predict(X_true).flatten()
#
# AttributeError: '_UserObject' object has no attribute 'predict'

# %%
save_path + f"{model_name}_{n}/trained_model"
# Out:
# './trainedModels/GMWB_PY/nolapse/LSTM_LoCap_mediumNoise_0/trained_model'

# %%
model_name = "LSTM_LoCap_highNoise"

MSE_train = np.zeros(n_rep)
MSE_test = np.zeros(n_rep)
MSE_true = np.zeros(n_rep)
VaR = np.zeros(n_rep)
CVaR = np.zeros(n_rep)
VaR_sns = np.zeros(n_rep)
CVaR_sns = np.zeros(n_rep)

for n in range(n_rep):
    
    print("Macro replication:", n + 1)

    loss_sns = np.load(cwd + lossFiles_highNoise[n])
    
    X_train, y_train, X_test, y_test, y_mean, y_std = preprocess.transform_data(rtn, loss_LN, True, test_size, seed, model="RNN")
    
    X_true, y_true = preprocess.transform_data(rtn, loss_T, training=False, y_mean=y_mean, y_std=y_std, model="RNN")
    
    y_true = np.array(y_true).flatten()

    if "REG" in model_name:
            
        X_train_Q, X_test_Q = generate_basis(X_train), generate_basis(X_test)
        X_true_Q = generate_basis(X_true)

        model = joblib.load(save_path + f"{model_name}_{n}/reg_Q.pkl")

        y_hat_train = model.predict(X_train_Q).flatten()
        y_hat_test = model.predict(X_test_Q).flatten()
        y_hat = model.predict(X_true_Q).flatten()

    else:
        model = tf.keras.models.load_model(save_path + f"{model_name}_{n}/trained_model")

        y_hat_train = model.predict(X_train).flatten()
        y_hat_test = model.predict(X_test).flatten()
        y_hat = model.predict(X_true).flatten()
    
    # Calculating MSE
    MSE_train[n] = np.mean((y_hat_train - y_train)**2)
    MSE_test[n] = np.mean((y_hat_test - y_test)**2)
    MSE_true[n] = np.mean((y_hat - y_true)**2)

    loss_hat = y_hat * y_std + y_mean
    
    q = np.sort(loss_hat)[-int(alpha * len(loss_hat))]
    
    VaR[n] = q
    CVaR[n] = np.mean(loss_hat[loss_hat > q])
    
    q = np.sort(loss_sns)[-int(alpha * len(loss_hat))]
    
    VaR_sns[n] = q
    CVaR_sns[n] = np.mean(loss_sns[loss_sns > q])
    
    np.save(save_path + f"{model_name}_{n}", loss_hat)
    
np.save(save_path + f"{model_name}_CVaR", CVaR)
np.save(save_path + f"{model_name}_VaR", VaR)
# Out:
# Macro replication: 1
# Data is split, training and test data has shape:
# (47000, 240, 1) (47000,) (3000, 240, 1) (3000,)
# 1099/1469 [=====================>........] - ETA: 3s
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[34], line 37
#      34 else:
#      35     model = tf.keras.models.load_model(save_path + f"{model_name}_{n}/trained_model")
# ---> 37     y_hat_train = model.predict(X_train).flatten()
#      38     y_hat_test = model.predict(X_test).flatten()
#      39     y_hat = model.predict(X_true).flatten()
#
# File ~\anaconda3\lib\site-packages\keras\utils\traceback_utils.py:65, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#      63 filtered_tb = None
#      64 try:
# ---> 65     return fn(*args, **kwargs)
#      66 except Exception as e:
#      67     filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File ~\anaconda3\lib\site-packages\keras\engine\training.py:2253, in Model.predict(self, x, batch_size, verbose, steps, callbacks, max_queue_size, workers, use_multiprocessing)
#    2251 for step in data_handler.steps():
#    2252     callbacks.on_predict_batch_begin(step)
# -> 2253     tmp_batch_outputs = self.predict_function(iterator)
#    2254     if data_handler.should_sync:
#    2255         context.async_wait()
#
# File ~\anaconda3\lib\site-packages\tensorflow\python\util\traceback_utils.py:150, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     148 filtered_tb = None
#     149 try:
# --> 150   return fn(*args, **kwargs)
#     151 except Exception as e:
#     152   filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File ~\anaconda3\lib\site-packages\tensorflow\python\eager\def_function.py:915, in Function.__call__(self, *args, **kwds)
#     912 compiler = "xla" if self._jit_compile else "nonXla"
#     914 with OptionalXlaContext(self._jit_compile):
# --> 915   result = self._call(*args, **kwds)
#     917 new_tracing_count = self.experimental_get_tracing_count()
#     918 without_tracing = (tracing_count == new_tracing_count)
#
# File ~\anaconda3\lib\site-packages\tensorflow\python\eager\def_function.py:954, in Function._call(self, *args, **kwds)
#     951 self._lock.release()
#     952 # In this case we have not created variables on the first call. So we can
#     953 # run the first trace but we should fail if variables are created.
# --> 954 results = self._stateful_fn(*args, **kwds)
#     955 if self._created_variables and not ALLOW_DYNAMIC_VARIABLE_CREATION:
#     956   raise ValueError("Creating variables on a non-first call to a function"
#     957                    " decorated with tf.function.")
#
# File ~\anaconda3\lib\site-packages\tensorflow\python\eager\function.py:2496, in Function.__call__(self, *args, **kwargs)
#    2493 with self._lock:
#    2494   (graph_function,
#    2495    filtered_flat_args) = self._maybe_define_function(args, kwargs)
# -> 2496 return graph_function._call_flat(
#    2497     filtered_flat_args, captured_inputs=graph_function.captured_inputs)
#
# File ~\anaconda3\lib\site-packages\tensorflow\python\eager\function.py:1862, in ConcreteFunction._call_flat(self, args, captured_inputs, cancellation_manager)
#    1858 possible_gradient_type = gradients_util.PossibleTapeGradientTypes(args)
#    1859 if (possible_gradient_type == gradients_util.POSSIBLE_GRADIENT_TYPES_NONE
#    1860     and executing_eagerly):
#    1861   # No tape is watching; skip to running the function.
# -> 1862   return self._build_call_outputs(self._inference_function.call(
#    1863       ctx, args, cancellation_manager=cancellation_manager))
#    1864 forward_backward = self._select_forward_and_backward_functions(
#    1865     args,
#    1866     possible_gradient_type,
#    1867     executing_eagerly)
#    1868 forward_function, args_with_tangents = forward_backward.forward()
#
# File ~\anaconda3\lib\site-packages\tensorflow\python\eager\function.py:499, in _EagerDefinedFunction.call(self, ctx, args, cancellation_manager)
#     497 with _InterpolateFunctionError(self):
#     498   if cancellation_manager is None:
# --> 499     outputs = execute.execute(
#     500         str(self.signature.name),
#     501         num_outputs=self._num_outputs,
#     502         inputs=args,
#     503         attrs=attrs,
#     504         ctx=ctx)
#     505   else:
#     506     outputs = execute.execute_with_cancellation(
#     507         str(self.signature.name),
#     508         num_outputs=self._num_outputs,
#    (...)
#     511         ctx=ctx,
#     512         cancellation_manager=cancellation_manager)
#
# File ~\anaconda3\lib\site-packages\tensorflow\python\eager\execute.py:54, in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      52 try:
#      53   ctx.ensure_initialized()
# ---> 54   tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
#      55                                       inputs, attrs, num_outputs)
#      56 except core._NotOkStatusException as e:
#      57   if name is not None:
#
# KeyboardInterrupt:

# %%
model_name = "LSTM_HiCap_LowNoise"

MSE_train = np.zeros(n_rep)
MSE_test = np.zeros(n_rep)
MSE_true = np.zeros(n_rep)
VaR = np.zeros(n_rep)
CVaR = np.zeros(n_rep)

for n in range(n_rep):
    
    print("Macro replication:", n + 1)

    loss_LN = np.load(cwd + lossFiles_lowNoise[n])
    
    X_train, y_train, X_test, y_test, y_mean, y_std = preprocess.transform_data(rtn, loss_LN, True, test_size, seed, model="RNN")
    
    X_true, y_true = preprocess.transform_data(rtn, loss_T, training=False, y_mean=y_mean, y_std=y_std, model="RNN")
    
    y_true = np.array(y_true).flatten()

    if "REG" in model_name:
            
        X_train_Q, X_test_Q = generate_basis(X_train), generate_basis(X_test)
        X_true_Q = generate_basis(X_true)

        model = joblib.load(save_path + f"{model_name}_{n}/reg_Q.pkl")

        y_hat_train = model.predict(X_train_Q).flatten()
        y_hat_test = model.predict(X_test_Q).flatten()
        y_hat = model.predict(X_true_Q).flatten()

    else:
        model = tf.keras.models.load_model(save_path + f"{model_name}_{n}/trained_model")

        y_hat_train = model.predict(X_train).flatten()
        y_hat_test = model.predict(X_test).flatten()
        y_hat = model.predict(X_true).flatten()
    
    # Calculating MSE
    MSE_train[n] = np.mean((y_hat_train - y_train)**2)
    MSE_test[n] = np.mean((y_hat_test - y_test)**2)
    MSE_true[n] = np.mean((y_hat - y_true)**2)

    loss_hat = y_hat * y_std + y_mean
    
    q = np.sort(loss_hat)[-int(alpha * len(loss_hat))]
    
    VaR[n] = q
    CVaR[n] = np.mean(loss_hat[loss_hat > q])
    
    np.save(save_path + f"{model_name}_{n}", loss_hat)

np.save(save_path + f"{model_name}_CVaR", CVaR)
np.save(save_path + f"{model_name}_VaR", VaR)
# Out:
# Macro replication: 1
# Data is split, training and test data has shape:
# (47000, 240, 1) (47000,) (3000, 240, 1) (3000,)
# 1469/1469 [==============================] - 18s 12ms/step
# 94/94 [==============================] - 1s 12ms/step
# 1563/1563 [==============================] - 18s 12ms/step
# Macro replication: 2
# Data is split, training and test data has shape:
# (47000, 240, 1) (47000,) (3000, 240, 1) (3000,)
# 1469/1469 [==============================] - 18s 12ms/step
# 94/94 [==============================] - 1s 12ms/step
# 1563/1563 [==============================] - 18s 12ms/step
# Macro replication: 3
# Data is split, training and test data has shape:
# (47000, 240, 1) (47000,) (3000, 240, 1) (3000,)
# 1469/1469 [==============================] - 18s 12ms/step
# 94/94 [==============================] - 1s 12ms/step
# 1563/1563 [==============================] - 18s 12ms/step
# Macro replication: 4
# Data is split, training and test data has shape:
# (47000, 240, 1) (47000,) (3000, 240, 1) (3000,)
# 1469/1469 [==============================] - 18s 12ms/step
# 94/94 [==============================] - 1s 11ms/step
# 1563/1563 [==============================] - 18s 12ms/step
# Macro replication: 5
# Data is split, training and test data has shape:
# (47000, 240, 1) (47000,) (3000, 240, 1) (3000,)
# 1469/1469 [==============================] - 18s 12ms/step
# 94/94 [==============================] - 1s 12ms/step
# 1563/1563 [==============================] - 19s 12ms/step
# Macro replication: 6
# Data is split, training and test data has shape:
# (47000, 240, 1) (47000,) (3000, 240, 1) (3000,)
# 1469/1469 [==============================] - 18s 12ms/step
# 94/94 [==============================] - 1s 11ms/step
# 1563/1563 [==============================] - 18s 12ms/step
# Macro replication: 7
# Data is split, training and test data has shape:
# (47000, 240, 1) (47000,) (3000, 240, 1) (3000,)
# 1469/1469 [==============================] - 18s 12ms/step
# 94/94 [==============================] - 1s 12ms/step
# 1563/1563 [==============================] - 18s 12ms/step
# Macro replication: 8
# Data is split, training and test data has shape:
# (47000, 240, 1) (47000,) (3000, 240, 1) (3000,)
# 1469/1469 [==============================] - 18s 12ms/step
# 94/94 [==============================] - 1s 12ms/step
# 1563/1563 [==============================] - 18s 12ms/step
# Macro replication: 9
# Data is split, training and test data has shape:
# (47000, 240, 1) (47000,) (3000, 240, 1) (3000,)
# 1469/1469 [==============================] - 18s 12ms/step
# 94/94 [==============================] - 1s 12ms/step
# 1563/1563 [==============================] - 18s 12ms/step
# Macro replication: 10
# Data is split, training and test data has shape:
# (47000, 240, 1) (47000,) (3000, 240, 1) (3000,)
# 1469/1469 [==============================] - 18s 12ms/step
# 94/94 [==============================] - 1s 12ms/step
# 1563/1563 [==============================] - 18s 12ms/step
# Macro replication: 11
# Data is split, training and test data has shape:
# (47000, 240, 1) (47000,) (3000, 240, 1) (3000,)
# 1469/1469 [==============================] - 18s 12ms/step
# 94/94 [==============================] - 1s 12ms/step
# 1563/1563 [==============================] - 18s 12ms/step
# Macro replication: 12
# Data is split, training and test data has shape:
# (47000, 240, 1) (47000,) (3000, 240, 1) (3000,)
# 1469/1469 [==============================] - 18s 12ms/step
# 94/94 [==============================] - 1s 12ms/step
# 1563/1563 [==============================] - 18s 12ms/step
# Macro replication: 13
# Data is split, training and test data has shape:
# (47000, 240, 1) (47000,) (3000, 240, 1) (3000,)
# 1469/1469 [==============================] - 18s 12ms/step
# 94/94 [==============================] - 1s 12ms/step
# 1563/1563 [==============================] - 18s 12ms/step
# Macro replication: 14
# Data is split, training and test data has shape:
# (47000, 240, 1) (47000,) (3000, 240, 1) (3000,)
# 1469/1469 [==============================] - 18s 12ms/step
# 94/94 [==============================] - 1s 12ms/step
# 1563/1563 [==============================] - 18s 12ms/step
# Macro replication: 15
# Data is split, training and test data has shape:
# (47000, 240, 1) (47000,) (3000, 240, 1) (3000,)
# 1469/1469 [==============================] - 18s 12ms/step
# 94/94 [==============================] - 1s 12ms/step
# 1563/1563 [==============================] - 18s 12ms/step
# Macro replication: 16
# Data is split, training and test data has shape:
# (47000, 240, 1) (47000,) (3000, 240, 1) (3000,)
# 1469/1469 [==============================] - 18s 12ms/step
# 94/94 [==============================] - 1s 12ms/step
# 1563/1563 [==============================] - 18s 12ms/step
# Macro replication: 17
# Data is split, training and test data has shape:
# (47000, 240, 1) (47000,) (3000, 240, 1) (3000,)
# 1469/1469 [==============================] - 18s 12ms/step
# 94/94 [==============================] - 1s 12ms/step
# 1563/1563 [==============================] - 18s 12ms/step
# Macro replication: 18
# Data is split, training and test data has shape:
# (47000, 240, 1) (47000,) (3000, 240, 1) (3000,)
# 1469/1469 [==============================] - 18s 12ms/step
# 94/94 [==============================] - 1s 12ms/step
# 1563/1563 [==============================] - 18s 12ms/step
# Macro replication: 19
# Data is split, training and test data has shape:
# (47000, 240, 1) (47000,) (3000, 240, 1) (3000,)
# 1469/1469 [==============================] - 18s 12ms/step
# 94/94 [==============================] - 1s 12ms/step
# 1563/1563 [==============================] - 18s 12ms/step
# Macro replication: 20
# Data is split, training and test data has shape:
# (47000, 240, 1) (47000,) (3000, 240, 1) (3000,)
# 1469/1469 [==============================] - 18s 12ms/step
# 94/94 [==============================] - 1s 12ms/step
# 1563/1563 [==============================] - 18s 12ms/step
# Macro replication: 21
# Data is split, training and test data has shape:
# (47000, 240, 1) (47000,) (3000, 240, 1) (3000,)
# 1469/1469 [==============================] - 18s 12ms/step
# 94/94 [==============================] - 1s 12ms/step
# 1563/1563 [==============================] - 18s 12ms/step
# Macro replication: 22
# Data is split, training and test data has shape:
# (47000, 240, 1) (47000,) (3000, 240, 1) (3000,)
# 1469/1469 [==============================] - 18s 12ms/step
# 94/94 [==============================] - 1s 12ms/step
# 1563/1563 [==============================] - 18s 12ms/step
# Macro replication: 23
# Data is split, training and test data has shape:
# (47000, 240, 1) (47000,) (3000, 240, 1) (3000,)
# 1469/1469 [==============================] - 18s 12ms/step
# 94/94 [==============================] - 1s 11ms/step
# 1563/1563 [==============================] - 18s 12ms/step
# Macro replication: 24
# Data is split, training and test data has shape:
# (47000, 240, 1) (47000,) (3000, 240, 1) (3000,)
# 1469/1469 [==============================] - 18s 12ms/step
# 94/94 [==============================] - 1s 11ms/step
# 1563/1563 [==============================] - 18s 12ms/step
# Macro replication: 25
# Data is split, training and test data has shape:
# (47000, 240, 1) (47000,) (3000, 240, 1) (3000,)
# 1469/1469 [==============================] - 18s 12ms/step
# 94/94 [==============================] - 1s 11ms/step
# 1563/1563 [==============================] - 18s 12ms/step
# Macro replication: 26
# Data is split, training and test data has shape:
# (47000, 240, 1) (47000,) (3000, 240, 1) (3000,)
# 1469/1469 [==============================] - 18s 12ms/step
# 94/94 [==============================] - 1s 12ms/step
# 1563/1563 [==============================] - 18s 12ms/step
# Macro replication: 27
# Data is split, training and test data has shape:
# (47000, 240, 1) (47000,) (3000, 240, 1) (3000,)
# 1469/1469 [==============================] - 18s 12ms/step
# 94/94 [==============================] - 1s 11ms/step
# 1563/1563 [==============================] - 18s 12ms/step
# Macro replication: 28
# Data is split, training and test data has shape:
# (47000, 240, 1) (47000,) (3000, 240, 1) (3000,)
# 1469/1469 [==============================] - 18s 12ms/step
# 94/94 [==============================] - 1s 12ms/step
# 1563/1563 [==============================] - 18s 12ms/step
# Macro replication: 29
# Data is split, training and test data has shape:
# (47000, 240, 1) (47000,) (3000, 240, 1) (3000,)
# 1469/1469 [==============================] - 18s 12ms/step
# 94/94 [==============================] - 1s 12ms/step
# 1563/1563 [==============================] - 18s 12ms/step
# Macro replication: 30
# Data is split, training and test data has shape:
# (47000, 240, 1) (47000,) (3000, 240, 1) (3000,)
# 1469/1469 [==============================] - 18s 12ms/step
# 94/94 [==============================] - 1s 11ms/step
# 1563/1563 [==============================] - 18s 12ms/step
# Macro replication: 31
# Data is split, training and test data has shape:
# (47000, 240, 1) (47000,) (3000, 240, 1) (3000,)
# 1469/1469 [==============================] - 18s 12ms/step
# 94/94 [==============================] - 1s 11ms/step
# 1563/1563 [==============================] - 18s 12ms/step
# Macro replication: 32
# Data is split, training and test data has shape:
# (47000, 240, 1) (47000,) (3000, 240, 1) (3000,)
# 1469/1469 [==============================] - 18s 12ms/step
# 94/94 [==============================] - 1s 12ms/step
# 1563/1563 [==============================] - 18s 12ms/step
# Macro replication: 33
# Data is split, training and test data has shape:
# (47000, 240, 1) (47000,) (3000, 240, 1) (3000,)
# 1469/1469 [==============================] - 18s 12ms/step
# 94/94 [==============================] - 1s 12ms/step
# 1563/1563 [==============================] - 18s 12ms/step
# Macro replication: 34
# Data is split, training and test data has shape:
# (47000, 240, 1) (47000,) (3000, 240, 1) (3000,)
# 1469/1469 [==============================] - 18s 12ms/step
# 94/94 [==============================] - 1s 11ms/step
# 1563/1563 [==============================] - 18s 11ms/step
# Macro replication: 35
# Data is split, training and test data has shape:
# (47000, 240, 1) (47000,) (3000, 240, 1) (3000,)
# 1469/1469 [==============================] - 18s 12ms/step
# 94/94 [==============================] - 1s 11ms/step
# 1563/1563 [==============================] - 18s 12ms/step
# Macro replication: 36
# Data is split, training and test data has shape:
# (47000, 240, 1) (47000,) (3000, 240, 1) (3000,)
# 1469/1469 [==============================] - 18s 12ms/step
# 94/94 [==============================] - 1s 11ms/step
# 1563/1563 [==============================] - 18s 12ms/step
# Macro replication: 37
# Data is split, training and test data has shape:
# (47000, 240, 1) (47000,) (3000, 240, 1) (3000,)
# 1469/1469 [==============================] - 18s 12ms/step
# 94/94 [==============================] - 1s 12ms/step
# 1563/1563 [==============================] - 18s 12ms/step
# Macro replication: 38
# Data is split, training and test data has shape:
# (47000, 240, 1) (47000,) (3000, 240, 1) (3000,)
# 1469/1469 [==============================] - 19s 12ms/step
# 94/94 [==============================] - 1s 12ms/step
# 1563/1563 [==============================] - 18s 12ms/step
# Macro replication: 39
# Data is split, training and test data has shape:
# (47000, 240, 1) (47000,) (3000, 240, 1) (3000,)
# 1469/1469 [==============================] - 18s 12ms/step
# 94/94 [==============================] - 1s 11ms/step
# 1563/1563 [==============================] - 18s 12ms/step
# Macro replication: 40
# Data is split, training and test data has shape:
# (47000, 240, 1) (47000,) (3000, 240, 1) (3000,)
# 1469/1469 [==============================] - 18s 12ms/step
# 94/94 [==============================] - 1s 12ms/step
# 1563/1563 [==============================] - 18s 12ms/step
# Macro replication: 41
# Data is split, training and test data has shape:
# (47000, 240, 1) (47000,) (3000, 240, 1) (3000,)
# 1469/1469 [==============================] - 18s 12ms/step
# 94/94 [==============================] - 1s 12ms/step
# 1563/1563 [==============================] - 18s 12ms/step
# Macro replication: 42
# Data is split, training and test data has shape:
# (47000, 240, 1) (47000,) (3000, 240, 1) (3000,)
# 1469/1469 [==============================] - 18s 12ms/step
# 94/94 [==============================] - 1s 12ms/step
# 1563/1563 [==============================] - 18s 12ms/step
# Macro replication: 43
# Data is split, training and test data has shape:
# (47000, 240, 1) (47000,) (3000, 240, 1) (3000,)
# 1469/1469 [==============================] - 19s 12ms/step
# 94/94 [==============================] - 1s 12ms/step
# 1563/1563 [==============================] - 18s 12ms/step
# Macro replication: 44
# Data is split, training and test data has shape:
# (47000, 240, 1) (47000,) (3000, 240, 1) (3000,)
# 1469/1469 [==============================] - 18s 12ms/step
# 94/94 [==============================] - 1s 12ms/step
# 1563/1563 [==============================] - 18s 12ms/step
# Macro replication: 45
# Data is split, training and test data has shape:
# (47000, 240, 1) (47000,) (3000, 240, 1) (3000,)
# 1469/1469 [==============================] - 18s 12ms/step
# 94/94 [==============================] - 1s 12ms/step
# 1563/1563 [==============================] - 18s 12ms/step
# Macro replication: 46
# Data is split, training and test data has shape:
# (47000, 240, 1) (47000,) (3000, 240, 1) (3000,)
# 1469/1469 [==============================] - 18s 12ms/step
# 94/94 [==============================] - 1s 12ms/step
# 1563/1563 [==============================] - 18s 12ms/step
# Macro replication: 47
# Data is split, training and test data has shape:
# (47000, 240, 1) (47000,) (3000, 240, 1) (3000,)
# 1469/1469 [==============================] - 18s 12ms/step
# 94/94 [==============================] - 1s 12ms/step
# 1563/1563 [==============================] - 18s 12ms/step
# Macro replication: 48
# Data is split, training and test data has shape:
# (47000, 240, 1) (47000,) (3000, 240, 1) (3000,)
# 1469/1469 [==============================] - 18s 12ms/step
# 94/94 [==============================] - 1s 11ms/step
# 1563/1563 [==============================] - 18s 11ms/step
# Macro replication: 49
# Data is split, training and test data has shape:
# (47000, 240, 1) (47000,) (3000, 240, 1) (3000,)
# 1469/1469 [==============================] - 18s 12ms/step
# 94/94 [==============================] - 1s 12ms/step
# 1563/1563 [==============================] - 18s 11ms/step
# Macro replication: 50
# Data is split, training and test data has shape:
# (47000, 240, 1) (47000,) (3000, 240, 1) (3000,)
# 1469/1469 [==============================] - 17s 11ms/step
# 94/94 [==============================] - 1s 11ms/step
# 1563/1563 [==============================] - 18s 11ms/step

# %%
np.load(save_path + )

# %%
model_name = "LSTM_HiCap_mediumNoise"

MSE_train = np.zeros(n_rep)
MSE_test = np.zeros(n_rep)
MSE_true = np.zeros(n_rep)
VaR = np.zeros(n_rep)
CVaR = np.zeros(n_rep)
VaR_sns = np.zeros(n_rep)
CVaR_sns = np.zeros(n_rep)

for n in range(n_rep):
    
    print("Macro replication:", n + 1)

    loss_sns = np.load(cwd + lossFiles_mediumNoise[n])
    
    X_train, y_train, X_test, y_test, y_mean, y_std = preprocess.transform_data(rtn, loss_LN, True, test_size, seed, model="RNN")
    
    X_true, y_true = preprocess.transform_data(rtn, loss_T, training=False, y_mean=y_mean, y_std=y_std, model="RNN")
    
    y_true = np.array(y_true).flatten()

    if "REG" in model_name:
            
        X_train_Q, X_test_Q = generate_basis(X_train), generate_basis(X_test)
        X_true_Q = generate_basis(X_true)

        model = joblib.load(save_path + f"{model_name}_{n}/reg_Q.pkl")

        y_hat_train = model.predict(X_train_Q).flatten()
        y_hat_test = model.predict(X_test_Q).flatten()
        y_hat = model.predict(X_true_Q).flatten()

    else:
        model = tf.keras.models.load_model(save_path + f"{model_name}_{n}/trained_model")

        y_hat_train = model.predict(X_train).flatten()
        y_hat_test = model.predict(X_test).flatten()
        y_hat = model.predict(X_true).flatten()
    
    # Calculating MSE
    MSE_train[n] = np.mean((y_hat_train - y_train)**2)
    MSE_test[n] = np.mean((y_hat_test - y_test)**2)
    MSE_true[n] = np.mean((y_hat - y_true)**2)

    loss_hat = y_hat * y_std + y_mean
    
    q = np.sort(loss_hat)[-int(alpha * len(loss_hat))]
    
    VaR[n] = q
    CVaR[n] = np.mean(loss_hat[loss_hat > q])
    
    q = np.sort(loss_sns)[-int(alpha * len(loss_hat))]
    
    VaR_sns[n] = q
    CVaR_sns[n] = np.mean(loss_sns[loss_sns > q])
    
    np.save(save_path + f"{model_name}_{n}", loss_hat)
    
np.save(save_path + f"{model_name}_CVaR", CVaR)
np.save(save_path + f"{model_name}_VaR", VaR)
# Out:
# Macro replication: 1
# Data is split, training and test data has shape:
# (47000, 240, 1) (47000,) (3000, 240, 1) (3000,)
# C:\Users\X\anaconda3\lib\site-packages\keras\saving\saved_model\load.py:107: RuntimeWarning: Unexpected end-group tag: Not all data was converted
#   metadata.ParseFromString(file_content)
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[36], line 37
#      34 else:
#      35     model = tf.keras.models.load_model(save_path + f"{model_name}_{n}/trained_model")
# ---> 37     y_hat_train = model.predict(X_train).flatten()
#      38     y_hat_test = model.predict(X_test).flatten()
#      39     y_hat = model.predict(X_true).flatten()
#
# AttributeError: '_UserObject' object has no attribute 'predict'

# %%
model_name = "LSTM_HiCap_highNoise"

MSE_train = np.zeros(n_rep)
MSE_test = np.zeros(n_rep)
MSE_true = np.zeros(n_rep)
VaR = np.zeros(n_rep)
CVaR = np.zeros(n_rep)
VaR_sns = np.zeros(n_rep)
CVaR_sns = np.zeros(n_rep)

for n in range(n_rep):
    
    print("Macro replication:", n + 1)

    loss_sns = np.load(cwd + lossFiles_highNoise[n])
    
    X_train, y_train, X_test, y_test, y_mean, y_std = preprocess.transform_data(rtn, loss_LN, True, test_size, seed, model="RNN")
    
    X_true, y_true = preprocess.transform_data(rtn, loss_T, training=False, y_mean=y_mean, y_std=y_std, model="RNN")
    
    y_true = np.array(y_true).flatten()

    if "REG" in model_name:
            
        X_train_Q, X_test_Q = generate_basis(X_train), generate_basis(X_test)
        X_true_Q = generate_basis(X_true)

        model = joblib.load(save_path + f"{model_name}_{n}/reg_Q.pkl")

        y_hat_train = model.predict(X_train_Q).flatten()
        y_hat_test = model.predict(X_test_Q).flatten()
        y_hat = model.predict(X_true_Q).flatten()

    else:
        model = tf.keras.models.load_model(save_path + f"{model_name}_{n}/trained_model")

        y_hat_train = model.predict(X_train).flatten()
        y_hat_test = model.predict(X_test).flatten()
        y_hat = model.predict(X_true).flatten()
    
    # Calculating MSE
    MSE_train[n] = np.mean((y_hat_train - y_train)**2)
    MSE_test[n] = np.mean((y_hat_test - y_test)**2)
    MSE_true[n] = np.mean((y_hat - y_true)**2)

    loss_hat = y_hat * y_std + y_mean
    
    q = np.sort(loss_hat)[-int(alpha * len(loss_hat))]
    
    VaR[n] = q
    CVaR[n] = np.mean(loss_hat[loss_hat > q])
    
    q = np.sort(loss_sns)[-int(alpha * len(loss_hat))]
    
    VaR_sns[n] = q
    CVaR_sns[n] = np.mean(loss_sns[loss_sns > q])
    
    np.save(save_path + f"{model_name}_{n}", loss_hat)
    
np.save(save_path + f"{model_name}_CVaR", CVaR)
np.save(save_path + f"{model_name}_VaR", VaR)
# Out:
# Macro replication: 1
# Data is split, training and test data has shape:
# (47000, 240, 1) (47000,) (3000, 240, 1) (3000,)
# 1469/1469 [==============================] - 18s 12ms/step
# 94/94 [==============================] - 1s 12ms/step
# 1563/1563 [==============================] - 18s 12ms/step
# Macro replication: 2
# Data is split, training and test data has shape:
# (47000, 240, 1) (47000,) (3000, 240, 1) (3000,)
# 1469/1469 [==============================] - 18s 12ms/step
# 94/94 [==============================] - 1s 12ms/step
# 1563/1563 [==============================] - 18s 12ms/step
# Macro replication: 3
# Data is split, training and test data has shape:
# (47000, 240, 1) (47000,) (3000, 240, 1) (3000,)
# 1469/1469 [==============================] - 18s 12ms/step
# 94/94 [==============================] - 1s 12ms/step
# 1563/1563 [==============================] - 18s 12ms/step
# Macro replication: 4
# Data is split, training and test data has shape:
# (47000, 240, 1) (47000,) (3000, 240, 1) (3000,)
# 1469/1469 [==============================] - 18s 12ms/step
# 94/94 [==============================] - 1s 12ms/step
# 1563/1563 [==============================] - 18s 12ms/step
# Macro replication: 5
# Data is split, training and test data has shape:
# (47000, 240, 1) (47000,) (3000, 240, 1) (3000,)
# 1469/1469 [==============================] - 18s 12ms/step
# 94/94 [==============================] - 1s 12ms/step
# 1563/1563 [==============================] - 18s 12ms/step
# Macro replication: 6
# Data is split, training and test data has shape:
# (47000, 240, 1) (47000,) (3000, 240, 1) (3000,)
# 1469/1469 [==============================] - 18s 12ms/step
# 94/94 [==============================] - 1s 11ms/step
# 1563/1563 [==============================] - 18s 11ms/step
# Macro replication: 7
# Data is split, training and test data has shape:
# (47000, 240, 1) (47000,) (3000, 240, 1) (3000,)
# 1469/1469 [==============================] - 18s 12ms/step
# 94/94 [==============================] - 1s 11ms/step
# 1563/1563 [==============================] - 18s 11ms/step
# Macro replication: 8
# Data is split, training and test data has shape:
# (47000, 240, 1) (47000,) (3000, 240, 1) (3000,)
# 1469/1469 [==============================] - 18s 12ms/step
# 94/94 [==============================] - 1s 11ms/step
# 1563/1563 [==============================] - 18s 11ms/step
# Macro replication: 9
# Data is split, training and test data has shape:
# (47000, 240, 1) (47000,) (3000, 240, 1) (3000,)
# 1469/1469 [==============================] - 18s 12ms/step
# 94/94 [==============================] - 1s 11ms/step
# 1563/1563 [==============================] - 18s 11ms/step
# Macro replication: 10
# Data is split, training and test data has shape:
# (47000, 240, 1) (47000,) (3000, 240, 1) (3000,)
# 1469/1469 [==============================] - 18s 12ms/step
# 94/94 [==============================] - 1s 11ms/step
# 1563/1563 [==============================] - 18s 11ms/step
# Macro replication: 11
# Data is split, training and test data has shape:
# (47000, 240, 1) (47000,) (3000, 240, 1) (3000,)
# 1469/1469 [==============================] - 18s 12ms/step
# 94/94 [==============================] - 1s 12ms/step
# 1563/1563 [==============================] - 18s 12ms/step
# Macro replication: 12
# Data is split, training and test data has shape:
# (47000, 240, 1) (47000,) (3000, 240, 1) (3000,)
# 1469/1469 [==============================] - 18s 12ms/step
# 94/94 [==============================] - 1s 11ms/step
# 1563/1563 [==============================] - 18s 11ms/step
# Macro replication: 13
# Data is split, training and test data has shape:
# (47000, 240, 1) (47000,) (3000, 240, 1) (3000,)
# 1469/1469 [==============================] - 18s 12ms/step
# 94/94 [==============================] - 1s 11ms/step
# 1563/1563 [==============================] - 18s 11ms/step
# Macro replication: 14
# Data is split, training and test data has shape:
# (47000, 240, 1) (47000,) (3000, 240, 1) (3000,)
# 1469/1469 [==============================] - 18s 12ms/step
# 94/94 [==============================] - 1s 11ms/step
# 1563/1563 [==============================] - 18s 11ms/step
# Macro replication: 15
# Data is split, training and test data has shape:
# (47000, 240, 1) (47000,) (3000, 240, 1) (3000,)
# 1469/1469 [==============================] - 18s 12ms/step
# 94/94 [==============================] - 1s 11ms/step
# 1563/1563 [==============================] - 18s 11ms/step
# Macro replication: 16
# Data is split, training and test data has shape:
# (47000, 240, 1) (47000,) (3000, 240, 1) (3000,)
# 1469/1469 [==============================] - 18s 12ms/step
# 94/94 [==============================] - 1s 12ms/step
# 1563/1563 [==============================] - 18s 11ms/step
# Macro replication: 17
# Data is split, training and test data has shape:
# (47000, 240, 1) (47000,) (3000, 240, 1) (3000,)
# 1469/1469 [==============================] - 18s 12ms/step
# 94/94 [==============================] - 1s 12ms/step
# 1563/1563 [==============================] - 18s 11ms/step
# Macro replication: 18
# Data is split, training and test data has shape:
# (47000, 240, 1) (47000,) (3000, 240, 1) (3000,)
# 1469/1469 [==============================] - 18s 12ms/step
# 94/94 [==============================] - 1s 11ms/step
# 1563/1563 [==============================] - 18s 11ms/step
# Macro replication: 19
# Data is split, training and test data has shape:
# (47000, 240, 1) (47000,) (3000, 240, 1) (3000,)
# 1469/1469 [==============================] - 17s 12ms/step
# 94/94 [==============================] - 1s 11ms/step
# 1563/1563 [==============================] - 18s 11ms/step
# Macro replication: 20
# Data is split, training and test data has shape:
# (47000, 240, 1) (47000,) (3000, 240, 1) (3000,)
# 1469/1469 [==============================] - 18s 12ms/step
# 94/94 [==============================] - 1s 11ms/step
# 1563/1563 [==============================] - 18s 11ms/step
# Macro replication: 21
# Data is split, training and test data has shape:
# (47000, 240, 1) (47000,) (3000, 240, 1) (3000,)
# 1469/1469 [==============================] - 18s 12ms/step
# 94/94 [==============================] - 1s 11ms/step
# 1563/1563 [==============================] - 18s 11ms/step
# Macro replication: 22
# Data is split, training and test data has shape:
# (47000, 240, 1) (47000,) (3000, 240, 1) (3000,)
# 1469/1469 [==============================] - 18s 12ms/step
# 94/94 [==============================] - 1s 11ms/step
# 1563/1563 [==============================] - 18s 11ms/step
# Macro replication: 23
# Data is split, training and test data has shape:
# (47000, 240, 1) (47000,) (3000, 240, 1) (3000,)
# 1469/1469 [==============================] - 18s 12ms/step
# 94/94 [==============================] - 1s 11ms/step
# 1563/1563 [==============================] - 18s 11ms/step
# Macro replication: 24
# Data is split, training and test data has shape:
# (47000, 240, 1) (47000,) (3000, 240, 1) (3000,)
# 1469/1469 [==============================] - 18s 12ms/step
# 94/94 [==============================] - 1s 11ms/step
# 1563/1563 [==============================] - 18s 11ms/step
# Macro replication: 25
# Data is split, training and test data has shape:
# (47000, 240, 1) (47000,) (3000, 240, 1) (3000,)
# 1469/1469 [==============================] - 18s 12ms/step
# 94/94 [==============================] - 1s 11ms/step
# 1563/1563 [==============================] - 18s 11ms/step
# Macro replication: 26
# Data is split, training and test data has shape:
# (47000, 240, 1) (47000,) (3000, 240, 1) (3000,)
# 1469/1469 [==============================] - 18s 12ms/step
# 94/94 [==============================] - 1s 11ms/step
# 1563/1563 [==============================] - 18s 11ms/step
# Macro replication: 27
# Data is split, training and test data has shape:
# (47000, 240, 1) (47000,) (3000, 240, 1) (3000,)
# 1469/1469 [==============================] - 18s 12ms/step
# 94/94 [==============================] - 1s 11ms/step
# 1563/1563 [==============================] - 18s 11ms/step
# Macro replication: 28
# Data is split, training and test data has shape:
# (47000, 240, 1) (47000,) (3000, 240, 1) (3000,)
# 1469/1469 [==============================] - 18s 12ms/step
# 94/94 [==============================] - 1s 11ms/step
# 1563/1563 [==============================] - 18s 11ms/step
# Macro replication: 29
# Data is split, training and test data has shape:
# (47000, 240, 1) (47000,) (3000, 240, 1) (3000,)
# 1469/1469 [==============================] - 18s 12ms/step
# 94/94 [==============================] - 1s 12ms/step
# 1563/1563 [==============================] - 18s 11ms/step
# Macro replication: 30
# Data is split, training and test data has shape:
# (47000, 240, 1) (47000,) (3000, 240, 1) (3000,)
# 1469/1469 [==============================] - 18s 12ms/step
# 94/94 [==============================] - 1s 11ms/step
# 1563/1563 [==============================] - 18s 11ms/step
# Macro replication: 31
# Data is split, training and test data has shape:
# (47000, 240, 1) (47000,) (3000, 240, 1) (3000,)
# 1469/1469 [==============================] - 17s 11ms/step
# 94/94 [==============================] - 1s 11ms/step
# 1563/1563 [==============================] - 18s 11ms/step
# Macro replication: 32
# Data is split, training and test data has shape:
# (47000, 240, 1) (47000,) (3000, 240, 1) (3000,)
# 1469/1469 [==============================] - 18s 12ms/step
# 94/94 [==============================] - 1s 11ms/step
# 1563/1563 [==============================] - 18s 11ms/step
# Macro replication: 33
# Data is split, training and test data has shape:
# (47000, 240, 1) (47000,) (3000, 240, 1) (3000,)
# 1469/1469 [==============================] - 18s 12ms/step
# 94/94 [==============================] - 1s 11ms/step
# 1563/1563 [==============================] - 18s 11ms/step
# Macro replication: 34
# Data is split, training and test data has shape:
# (47000, 240, 1) (47000,) (3000, 240, 1) (3000,)
# 1469/1469 [==============================] - 18s 12ms/step
# 94/94 [==============================] - 1s 12ms/step
# 1563/1563 [==============================] - 18s 11ms/step
# Macro replication: 35
# Data is split, training and test data has shape:
# (47000, 240, 1) (47000,) (3000, 240, 1) (3000,)
# 1469/1469 [==============================] - 18s 12ms/step
# 94/94 [==============================] - 1s 12ms/step
# 1563/1563 [==============================] - 18s 11ms/step
# Macro replication: 36
# Data is split, training and test data has shape:
# (47000, 240, 1) (47000,) (3000, 240, 1) (3000,)
# 1469/1469 [==============================] - 18s 12ms/step
# 94/94 [==============================] - 1s 11ms/step
# 1563/1563 [==============================] - 18s 11ms/step
# Macro replication: 37
# Data is split, training and test data has shape:
# (47000, 240, 1) (47000,) (3000, 240, 1) (3000,)
# 1469/1469 [==============================] - 18s 12ms/step
# 94/94 [==============================] - 1s 11ms/step
# 1563/1563 [==============================] - 18s 11ms/step
# Macro replication: 38
# Data is split, training and test data has shape:
# (47000, 240, 1) (47000,) (3000, 240, 1) (3000,)
# 1469/1469 [==============================] - 18s 12ms/step
# 94/94 [==============================] - 1s 11ms/step
# 1563/1563 [==============================] - 18s 11ms/step
# Macro replication: 39
# Data is split, training and test data has shape:
# (47000, 240, 1) (47000,) (3000, 240, 1) (3000,)
# 1469/1469 [==============================] - 18s 12ms/step
# 94/94 [==============================] - 1s 12ms/step
# 1563/1563 [==============================] - 18s 11ms/step
# Macro replication: 40
# Data is split, training and test data has shape:
# (47000, 240, 1) (47000,) (3000, 240, 1) (3000,)
# 1469/1469 [==============================] - 18s 12ms/step
# 94/94 [==============================] - 1s 11ms/step
# 1563/1563 [==============================] - 18s 11ms/step
# Macro replication: 41
# Data is split, training and test data has shape:
# (47000, 240, 1) (47000,) (3000, 240, 1) (3000,)
# 1469/1469 [==============================] - 18s 12ms/step
# 94/94 [==============================] - 1s 11ms/step
# 1563/1563 [==============================] - 18s 11ms/step
# Macro replication: 42
# Data is split, training and test data has shape:
# (47000, 240, 1) (47000,) (3000, 240, 1) (3000,)
# 1469/1469 [==============================] - 18s 12ms/step
# 94/94 [==============================] - 1s 11ms/step
# 1563/1563 [==============================] - 18s 11ms/step
# Macro replication: 43
# Data is split, training and test data has shape:
# (47000, 240, 1) (47000,) (3000, 240, 1) (3000,)
# 1469/1469 [==============================] - 18s 12ms/step
# 94/94 [==============================] - 1s 11ms/step
# 1563/1563 [==============================] - 18s 11ms/step
# Macro replication: 44
# Data is split, training and test data has shape:
# (47000, 240, 1) (47000,) (3000, 240, 1) (3000,)
# 1469/1469 [==============================] - 18s 12ms/step
# 94/94 [==============================] - 1s 11ms/step
# 1563/1563 [==============================] - 18s 11ms/step
# Macro replication: 45
# Data is split, training and test data has shape:
# (47000, 240, 1) (47000,) (3000, 240, 1) (3000,)
# 1469/1469 [==============================] - 18s 12ms/step
# 94/94 [==============================] - 1s 11ms/step
# 1563/1563 [==============================] - 18s 11ms/step
# Macro replication: 46
# Data is split, training and test data has shape:
# (47000, 240, 1) (47000,) (3000, 240, 1) (3000,)
# 1469/1469 [==============================] - 18s 12ms/step
# 94/94 [==============================] - 1s 11ms/step
# 1563/1563 [==============================] - 18s 11ms/step
# Macro replication: 47
# Data is split, training and test data has shape:
# (47000, 240, 1) (47000,) (3000, 240, 1) (3000,)
# 1469/1469 [==============================] - 18s 12ms/step
# 94/94 [==============================] - 1s 11ms/step
# 1563/1563 [==============================] - 18s 11ms/step
# Macro replication: 48
# Data is split, training and test data has shape:
# (47000, 240, 1) (47000,) (3000, 240, 1) (3000,)
# 1469/1469 [==============================] - 18s 12ms/step
# 94/94 [==============================] - 1s 11ms/step
# 1563/1563 [==============================] - 18s 11ms/step
# Macro replication: 49
# Data is split, training and test data has shape:
# (47000, 240, 1) (47000,) (3000, 240, 1) (3000,)
# 1469/1469 [==============================] - 18s 12ms/step
# 94/94 [==============================] - 1s 12ms/step
# 1563/1563 [==============================] - 18s 11ms/step
# Macro replication: 50
# Data is split, training and test data has shape:
# (47000, 240, 1) (47000,) (3000, 240, 1) (3000,)
# 1469/1469 [==============================] - 18s 12ms/step
# 94/94 [==============================] - 1s 11ms/step
# 1563/1563 [==============================] - 18s 11ms/step

# %%
CVaR
# Out:
# array([191.59718323, 192.7999115 , 187.66708374, 178.13920593,
#        177.82110596, 191.9263916 , 201.66392517, 182.33062744,
#        188.07392883, 184.46936035, 185.80726624, 195.70527649,
#        193.88064575, 188.69093323, 202.32910156, 191.23391724,
#        186.82107544, 192.24858093, 188.99967957, 189.53094482,
#        199.81982422, 187.72319031, 180.00788879, 190.52685547,
#        177.1993866 , 184.67904663, 189.87522888, 186.64553833,
#        196.33110046, 187.88674927, 194.87004089, 186.13815308,
#        202.75280762, 181.35827637, 196.9294281 , 190.70487976,
#        187.24661255, 192.81176758, 193.301651  , 188.58738708,
#        182.11500549, 190.33430481, 187.87295532, 184.65774536,
#        196.37882996, 179.79077148, 199.78816223, 176.16635132,
#        188.19007874, 190.21382141])
