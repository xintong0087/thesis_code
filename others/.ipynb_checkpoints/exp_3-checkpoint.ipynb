# %%
import numpy as np
import pandas as pd

import matplotlib.pyplot as plt

import os

import preprocess, fit_nn, evaluate

VA_type = "GMWB"
lapse_type = "nolapse"

cwd = f"../sim_VA/result/{VA_type}/{lapse_type}/"
save_path = f"./trainedModels/{VA_type}_PY/{lapse_type}/"

if not os.path.exists(save_path):
    os.makedirs(save_path)

price = np.load(cwd + f"outerScenarios_{VA_type}_RS_{lapse_type}.npy")
rtn = (price[:, 1:] - price[:, :-1]) / price[:, :-1]

substring_SNS = f"hedgingLoss_{VA_type}_RS_1000_{lapse_type}"

substring_lowNoise = f"hedgingLoss_{VA_type}_RS_100_{lapse_type}"
substring_mediumNoise = f"hedgingLoss_{VA_type}_RS_010_{lapse_type}"
substring_highNoise = f"hedgingLoss_{VA_type}_RS_001_{lapse_type}"

lossFiles_lowNoise = [file for file in os.listdir(cwd) if substring_lowNoise in file and os.path.isfile(os.path.join(cwd, file))]
lossFiles_mediumNoise = [file for file in os.listdir(cwd) if substring_mediumNoise in file and os.path.isfile(os.path.join(cwd, file))]
lossFiles_highNoise = [file for file in os.listdir(cwd) if substring_highNoise in file and os.path.isfile(os.path.join(cwd, file))]

# LoCap LSTM, mediumNoise GMWB Datasets

model_name = "LSTM"
recurrent_layer_size = [32, 4]
dense_layer_size = 32
activation_function = "tanh"
lr = 0.001
dropout = 0.1
decay_rate = 0.9
patience = 100

test_size = 3000
seed = 22

n_epochs = 1000
batch_size = 8192

n_rep = 50

save_name = "LSTM_LoCap_highNoise"

for rep in range(1, n_rep):
    loss_file = lossFiles_highNoise[rep]
    X_train, y_train, X_test, y_test, y_mean, y_std = preprocess.transform_data(rtn, np.load(cwd + loss_file), True, test_size, seed)

    # Build and train model
    model = fit_nn.build_model(X_train, 
                               model_name, recurrent_layer_size, dense_layer_size, 
                               activation_function, lr, dropout, decay_rate)

    path = save_path + f"{save_name}_{rep}/"
    model_trained, running_time = fit_nn.train_model(X_train, y_train, model, n_epochs, batch_size, patience, save_path)

    # Save model
    model_trained.save(path + f"trained_model")


# HiCap LSTM, mediumNoise GMWB Datasets
model_name = "LSTM"
recurrent_layer_size = [128, 16]
dense_layer_size = 64

save_name = "LSTM_HiCap_highNoise"

for rep in range(n_rep):
    loss_file = lossFiles_highNoise[rep]
    X_train, y_train, X_test, y_test, y_mean, y_std = preprocess.transform_data(rtn, np.load(cwd + loss_file), True, test_size, seed)

    # Build and train model
    model = fit_nn.build_model(X_train, 
                               model_name, recurrent_layer_size, dense_layer_size, 
                               activation_function, lr, dropout, decay_rate)

    path = save_path + f"{save_name}_{rep}/"
    model_trained, running_time = fit_nn.train_model(X_train, y_train, model, n_epochs, batch_size, patience, save_path)

    # Save model
    model_trained.save(path + f"trained_model")
# Out:
# Data is split, training and test data has shape:
# (47000, 240, 1) (47000,) (3000, 240, 1) (3000,)
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm (LSTM)                 (None, 240, 32)           4352
#
#  lstm_1 (LSTM)               (None, 240, 4)            592
#
#  flatten (Flatten)           (None, 960)               0
#
#  dense (Dense)               (None, 32)                30752
#
#  dropout (Dropout)           (None, 32)                0
#
#  dense_1 (Dense)             (None, 1)                 33
#
# =================================================================
# Total params: 35,729
# Trainable params: 35,729
# Non-trainable params: 0
# _________________________________________________________________
# None
# Epoch 1
# Epoch 400/1000
# 6/6 [==============================] - 1s 107ms/step - loss: 0.6009 - mean_squared_error: 0.6009 - val_loss: 0.6399 - val_mean_squared_error: 0.6399
# Epoch 401/1000
# 6/6 [==============================] - 3s 583ms/step - loss: 0.5986 - mean_squared_error: 0.5986 - val_loss: 0.6366 - val_mean_squared_error: 0.6366
# Epoch 402/1000
# 6/6 [==============================] - 3s 581ms/step - loss: 0.5945 - mean_squared_error: 0.5945 - val_loss: 0.6347 - val_mean_squared_error: 0.6347
# Epoch 403/1000
# 6/6 [==============================] - 1s 106ms/step - loss: 0.5967 - mean_squared_error: 0.5967 - val_loss: 0.6368 - val_mean_squared_error: 0.6368
# Epoch 404/1000
# 6/6 [==============================] - 3s 580ms/step - loss: 0.5958 - mean_squared_error: 0.5958 - val_loss: 0.6402 - val_mean_squared_error: 0.6402
# Epoch 405/1000
# 6/6 [==============================] - 3s 586ms/step - loss: 0.5993 - mean_squared_error: 0.5993 - val_loss: 0.6341 - val_mean_squared_error: 0.6341
# Epoch 406/1000
# 6/6 [==============================] - 1s 105ms/step - loss: 0.5946 - mean_squared_error: 0.5946 - val_loss: 0.6352 - val_mean_squared_error: 0.6352
# Epoch 407/1000
# 6/6 [==============================] - 3s 581ms/step - loss: 0.5955 - mean_squared_error: 0.5955 - val_loss: 0.6351 - val_mean_squared_error: 0.6351
# Epoch 408/1000
# 6/6 [==============================] - 1s 105ms/step - loss: 0.5955 - mean_squared_error: 0.5955 - val_loss: 0.6353 - val_mean_squared_error: 0.6353
# Epoch 409/1000
# 6/6 [==============================] - 3s 102ms/step - loss: 0.5978 - mean_squared_error: 0.5978 - val_loss: 0.6342 - val_mean_squared_error: 0.6342
# Epoch 410/1000
# 6/6 [==============================] - 3s 582ms/step - loss: 0.5947 - mean_squared_error: 0.5947 - val_loss: 0.6332 - val_mean_squared_error: 0.6332
# Epoch 411/1000
# 6/6 [==============================] - 1s 106ms/step - loss: 0.5929 - mean_squared_error: 0.5929 - val_loss: 0.6332 - val_mean_squared_error: 0.6332
# Epoch 412/1000
# 6/6 [==============================] - 3s 585ms/step - loss: 0.5951 - mean_squared_error: 0.5951 - val_loss: 0.6358 - val_mean_squared_error: 0.6358
# Epoch 413/1000
# 6/6 [==============================] - 3s 582ms/step - loss: 0.5960 - mean_squared_error: 0.5960 - val_loss: 0.6316 - val_mean_squared_error: 0.6316
# Epoch 414/1000
# 6/6 [==============================] - 1s 102ms/step - loss: 0.5959 - mean_squared_error: 0.5959 - val_loss: 0.6363 - val_mean_squared_error: 0.6363
# Epoch 415/1000
# 1/6 [====>.........................] - ETA: 0s - loss: 0.5986 - mean_squared_error: 0.5986
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[1], line 63
#      58 model = fit_nn.build_model(X_train,
#      59                            model_name, recurrent_layer_size, dense_layer_size,
#      60                            activation_function, lr, dropout, decay_rate)
#      62 path = save_path + f"{save_name}_{rep}/"
# ---> 63 model_trained, running_time = fit_nn.train_model(X_train, y_train, model, n_epochs, batch_size, patience, save_path)
#      65 # Save model
#      66 model_trained.save(path + f"trained_model")
#
# File ~\Documents\GitHub\VA_Experiments\fit_nn.py:65, in train_model(X, y, model, n_epochs, batch_size, patience, save_path)
#      61 logger = tf.keras.callbacks.CSVLogger(filename, separator=",", append=True)
#      63 start = time.time()
# ---> 65 history = model.fit(X, y, epochs=n_epochs,
#      66                     batch_size=batch_size,
#      67                     verbose=1,
#      68                     validation_split=0.1,
#      69                     callbacks=[callback, logger])
#      71 execution_time = time.time() - start
#      73 return model, execution_time
#
# File ~\anaconda3\lib\site-packages\keras\utils\traceback_utils.py:65, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#      63 filtered_tb = None
#      64 try:
# ---> 65     return fn(*args, **kwargs)
#      66 except Exception as e:
#      67     filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File ~\anaconda3\lib\site-packages\keras\engine\training.py:1570, in Model.fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq, max_queue_size, workers, use_multiprocessing)
#    1568 logs = tmp_logs
#    1569 end_step = step + data_handler.step_increment
# -> 1570 callbacks.on_train_batch_end(end_step, logs)
#    1571 if self.stop_training:
#    1572     break
#
# File ~\anaconda3\lib\site-packages\keras\callbacks.py:470, in CallbackList.on_train_batch_end(self, batch, logs)
#     463 """Calls the `on_train_batch_end` methods of its callbacks.
#     464
#     465 Args:
#     466     batch: Integer, index of batch within the current epoch.
#     467     logs: Dict. Aggregated metric results up until this batch.
#     468 """
#     469 if self._should_call_train_batch_hooks:
# --> 470     self._call_batch_hook(ModeKeys.TRAIN, "end", batch, logs=logs)
#
# File ~\anaconda3\lib\site-packages\keras\callbacks.py:317, in CallbackList._call_batch_hook(self, mode, hook, batch, logs)
#     315     self._call_batch_begin_hook(mode, batch, logs)
#     316 elif hook == "end":
# --> 317     self._call_batch_end_hook(mode, batch, logs)
#     318 else:
#     319     raise ValueError(
#     320         f"Unrecognized hook: {hook}. "
#     321         'Expected values are ["begin", "end"]'
#     322     )
#
# File ~\anaconda3\lib\site-packages\keras\callbacks.py:340, in CallbackList._call_batch_end_hook(self, mode, batch, logs)
#     337     batch_time = time.time() - self._batch_start_time
#     338     self._batch_times.append(batch_time)
# --> 340 self._call_batch_hook_helper(hook_name, batch, logs)
#     342 if len(self._batch_times) >= self._num_batches_for_timing_check:
#     343     end_hook_name = hook_name
#
# File ~\anaconda3\lib\site-packages\keras\callbacks.py:388, in CallbackList._call_batch_hook_helper(self, hook_name, batch, logs)
#     386 for callback in self.callbacks:
#     387     hook = getattr(callback, hook_name)
# --> 388     hook(batch, logs)
#     390 if self._check_timing:
#     391     if hook_name not in self._hook_times:
#
# File ~\anaconda3\lib\site-packages\keras\callbacks.py:1081, in ProgbarLogger.on_train_batch_end(self, batch, logs)
#    1080 def on_train_batch_end(self, batch, logs=None):
# -> 1081     self._batch_update_progbar(batch, logs)
#
# File ~\anaconda3\lib\site-packages\keras\callbacks.py:1157, in ProgbarLogger._batch_update_progbar(self, batch, logs)
#    1153     self.seen += add_seen
#    1155 if self.verbose == 1:
#    1156     # Only block async when verbose = 1.
# -> 1157     logs = tf_utils.sync_to_numpy_or_python_type(logs)
#    1158     self.progbar.update(self.seen, list(logs.items()), finalize=False)
#
# File ~\anaconda3\lib\site-packages\keras\utils\tf_utils.py:635, in sync_to_numpy_or_python_type(tensors)
#     632         return t
#     633     return t.item() if np.ndim(t) == 0 else t
# --> 635 return tf.nest.map_structure(_to_single_numpy_or_python_type, tensors)
#
# File ~\anaconda3\lib\site-packages\tensorflow\python\util\nest.py:917, in map_structure(func, *structure, **kwargs)
#     913 flat_structure = (flatten(s, expand_composites) for s in structure)
#     914 entries = zip(*flat_structure)
#     916 return pack_sequence_as(
# --> 917     structure[0], [func(*x) for x in entries],
#     918     expand_composites=expand_composites)
#
# File ~\anaconda3\lib\site-packages\tensorflow\python\util\nest.py:917, in <listcomp>(.0)
#     913 flat_structure = (flatten(s, expand_composites) for s in structure)
#     914 entries = zip(*flat_structure)
#     916 return pack_sequence_as(
# --> 917     structure[0], [func(*x) for x in entries],
#     918     expand_composites=expand_composites)
#
# File ~\anaconda3\lib\site-packages\keras\utils\tf_utils.py:628, in sync_to_numpy_or_python_type.<locals>._to_single_numpy_or_python_type(t)
#     625 def _to_single_numpy_or_python_type(t):
#     626     # Don't turn ragged or sparse tensors to NumPy.
#     627     if isinstance(t, tf.Tensor):
# --> 628         t = t.numpy()
#     629     # Strings, ragged and sparse tensors don't have .item(). Return them
#     630     # as-is.
#     631     if not isinstance(t, (np.ndarray, np.generic)):
#
# File ~\anaconda3\lib\site-packages\tensorflow\python\framework\ops.py:1157, in _EagerTensorBase.numpy(self)
#    1134 """Copy of the contents of this Tensor into a NumPy array or scalar.
#    1135
#    1136 Unlike NumPy arrays, Tensors are immutable, so this method has to copy
#    (...)
#    1154     NumPy dtype.
#    1155 """
#    1156 # TODO(slebedev): Consider avoiding a copy for non-CPU or remote tensors.
# -> 1157 maybe_arr = self._numpy()  # pylint: disable=protected-access
#    1158 return maybe_arr.copy() if isinstance(maybe_arr, np.ndarray) else maybe_arr
#
# File ~\anaconda3\lib\site-packages\tensorflow\python\framework\ops.py:1123, in _EagerTensorBase._numpy(self)
#    1121 def _numpy(self):
#    1122   try:
# -> 1123     return self._numpy_internal()
#    1124   except core._NotOkStatusException as e:  # pylint: disable=protected-access
#    1125     raise core._status_to_exception(e) from None
#
# KeyboardInterrupt:
