# %%
import tensorflow as tf
from tensorflow.keras import layers, models

import numpy as np
import os

import preprocess

# %%
# Define shared LSTM layers
def build_shared_lstm(input_shape):
    inputs = layers.Input(shape=(input_shape))
    x = layers.LSTM(32, return_sequences=True)(inputs)
    x = layers.LSTM(4, return_sequences=True)(x)
    # Flatten the output of the LSTM layers
    x = layers.Flatten()(x)
    return inputs, x

# Define task-specific fully connected layers
def task_specific_layers(shared_output):
    x = layers.Dense(32, activation='relu')(shared_output)
    x = layers.Dropout(0.1)(x)
    output = layers.Dense(1)(x)
    return output

# Input shape (for example, time series length of 100 with 10 features)
input_shape = (240, 1)

# Define shared LSTM layers
inputs, shared_output = build_shared_lstm(input_shape)

# Define task-specific outputs
output_task_1 = task_specific_layers(shared_output)  # Task 1 
output_task_2 = task_specific_layers(shared_output)  # Task 2 
# output_task_3 = task_specific_layers(shared_output)  # Task 3 

# Create a model with multiple outputs
model = models.Model(inputs=inputs, outputs=[output_task_1, output_task_2])

lr_schedule = tf.keras.optimizers.schedules.ExponentialDecay(initial_learning_rate=0.0005,
                                                             decay_steps=1000,
                                                             decay_rate=0.9)

optimizer = tf.keras.optimizers.Adam(lr_schedule)

# Compile the model with task-specific losses and metrics
model.compile(optimizer=optimizer,
              loss=['mean_squared_error', 'mean_squared_error'])

target_contract = "GMWB"
target_lapse = "nolapse"
target_noiseLevel = "LowNoise"
target_dataSize = 50000
test_size = 0
seed = 22
patience = 50
n_epochs = 3000
batch_size = 4096

cwd = f"../sim_VA/result/{target_contract}/{target_lapse}/"

price = np.load(cwd + f"outerScenarios_{target_contract}_RS_{target_lapse}.npy")
rtn = (price[:, 1:] - price[:, :-1]) / price[:, :-1]

if target_noiseLevel == "LowNoise":
    N = 100
else:
    N = 10

substring = f"hedgingLoss_{target_contract}_RS_{N}_{target_lapse}"
loss_file = [file for file in os.listdir(cwd) if substring in file and os.path.isfile(os.path.join(cwd, file))][0]


X_train, y_train_1, X_test, y_test, y_mean, y_std = preprocess.transform_data(rtn, np.load(cwd + loss_file), True, test_size, seed,
                                                                            part=True, part_size=target_dataSize)

loss = np.load("./GMMB.npy")

_, y_train_2, _, _, _, _ = preprocess.transform_data(rtn, loss, True, test_size, seed,
                                                     part=True, part_size=target_dataSize)


# Fit the model
callback = tf.keras.callbacks.EarlyStopping(monitor='val_loss', patience=patience)

history = model.fit(X_train, (y_train_1, y_train_2), epochs=n_epochs,
                    batch_size=batch_size,
                    verbose=1,
                    validation_split=0.1,
                    callbacks=[callback])

model.save("./multiTask_model_50000_extensive.keras")
# Out:
# Data is split, training and test data has shape:
# (50000, 240, 1) (50000,) (50000, 240, 1) (50000,)
# Data is split, training and test data has shape:
# (50000, 240, 1) (50000,) (50000, 240, 1) (50000,)
# Epoch 1/3000
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 15s 1s/step - dense_5_loss: 0.9956 - dense_7_loss: 1.0012 - loss: 1.9968 - val_dense_5_loss: 0.9777 - val_dense_7_loss: 0.8657 - val_loss: 1.8933
# Epoch 2/3000
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 12s 1s/step - dense_5_loss: 0.9694 - dense_7_loss: 0.9453 - loss: 1.9147 - val_dense_5_loss: 0.9186 - val_dense_7_loss: 0.7816 - val_loss: 1.7514
# Epoch 3/3000
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 12s 1s/step - dense_5_loss: 0.9023 - dense_7_loss: 0.8363 - loss: 1.7386 - val_dense_5_loss: 0.8012 - val_dense_7_loss: 0.6057 - val_loss: 1.4646
# Epoch 4/3000
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 13s 1s/step - dense_5_loss: 0.7909 - dense_7_loss: 0.6260 - loss: 1.4169 - val_dense_5_loss: 0.7169 - val_dense_7_loss: 0.4632 - val_loss: 1.2349
# Epoch 5/3000
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 12s 1s/step - dense_5_loss: 0.7367 - dense_7_loss: 0.4994 - loss: 1.2361 - val_dense_5_loss: 0.6904 - val_dense_7_loss: 0.3821 - val_loss: 1.1279
# Epoch 6/3000
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 13s 1s/step - dense_5_loss: 0.7249 - dense_7_loss: 0.4564 - loss: 1.1813 - val_dense_5_loss: 0.6856 - val_dense_7_loss: 0.3515 - val_loss: 1.0899
# Epoch 7/3000
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 12s 1s/step - dense_5_loss: 0.7134 - dense_7_loss: 0.4068 - loss: 1.1202 - val_dense_5_loss: 0.6783 - val_dense_7_loss: 0.3341 - val_loss: 1.0628
# Epoch 8/3000
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 12s 1s/step - dense_5_loss: 0.7052 - dense_7_loss: 0.4059 - loss: 1.1111 - val_dense_5_loss: 0.6657 - val_dense_7_loss: 0.3069 - val_loss: 1.0209
# Epoch 9/3000
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 12s 1s/step - dense_5_loss: 0.6793 - dense_7_loss: 0.3541 - loss: 1.0334 - val_dense_5_loss: 0.6486 - val_dense_7_loss: 0.2769 - val_loss: 0.9699
# Epoch 10/3000
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 12s 1s/step - dense_5_loss: 0.6665 - dense_7_loss: 0.3117 - loss: 0.9782 - val_dense_5_loss: 0.6112 - val_dense_7_loss: 0.2147 - val_loss: 0.8631
# Epoch 11/3000
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 12s 1s/step - dense_5_loss: 0.6160 - dense_7_loss: 0.2435 - loss: 0.8596 - val_dense_5_loss: 0.5533 - val_dense_7_loss: 0.2087 - val_loss: 0.7851
# Epoch 12/3000
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 12s 1s/step - dense_5_loss: 0.5564 - dense_7_loss: 0.2429 - loss: 0.7993 - val_dense_5_loss: 0.5279 - val_dense_7_loss: 0.1800 - val_loss: 0.7235
# Epoch 13/3000
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 12s 1s/step - dense_5_loss: 0.5247 - dense_7_loss: 0.2119 - loss: 0.7366 - val_dense_5_loss: 0.5045 - val_dense_7_loss: 0.1566 - val_loss: 0.6783
# Epoch 14/3000
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 12s 1s/step - dense_5_loss: 0.5052 - dense_7_loss: 0.1917 - loss: 0.6969 - val_dense_5_loss: 0.4914 - val_dense_7_loss: 0.1448 - val_loss: 0.6513
# Epoch 15/3000
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 12s 1s/step - dense_5_loss: 0.5005 - dense_7_loss: 0.1893 - loss: 0.6898 - val_dense_5_loss: 0.4798 - val_dense_7_loss: 0.1398 - val_loss: 0.6343
# Epoch 16/3000
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 12s 1s/step - dense_5_loss: 0.4910 - dense_7_loss: 0.1784 - loss: 0.6694 - val_dense_5_loss: 0.4768 - val_dense_7_loss: 0.1413 - val_loss: 0.6367
# Epoch 17/3000
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 12s 1s/step - dense_5_loss: 0.4882 - dense_7_loss: 0.1843 - loss: 0.6724 - val_dense_5_loss: 0.4604 - val_dense_7_loss: 0.1254 - val_loss: 0.6011
# Epoch 18/3000
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 12s 1s/step - dense_5_loss: 0.4733 - dense_7_loss: 0.1647 - loss: 0.6381 - val_dense_5_loss: 0.4530 - val_dense_7_loss: 0.1187 - val_loss: 0.5879
# Epoch 19/3000
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 13s 1s/step - dense_5_loss: 0.4681 - dense_7_loss: 0.1712 - loss: 0.6393 - val_dense_5_loss: 0.4434 - val_dense_7_loss: 0.1123 - val_loss: 0.5707
# Epoch 20/3000
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 12s 1s/step - dense_5_loss: 0.4621 - dense_7_loss: 0.1622 - loss: 0.6244 - val_dense_5_loss: 0.4338 - val_dense_7_loss: 0.1079 - val_loss: 0.5560
# Epoch 21/3000
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 12s 1s/step - dense_5_loss: 0.4544 - dense_7_loss: 0.1563 - loss: 0.6108 - val_dense_5_loss: 0.4261 - val_dense_7_loss: 0.1036 - val_loss: 0.5436
# Epoch 22/3000
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 12s 1s/step - dense_5_loss: 0.4445 - dense_7_loss: 0.1466 - loss: 0.5911 - val_dense_5_loss: 0.4141 - val_dense_7_loss: 0.1003 - val_loss: 0.5301
# Epoch 23/3000
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 12s 1s/step - dense_5_loss: 0.4379 - dense_7_loss: 0.1477 - loss: 0.5856 - val_dense_5_loss: 0.4045 - val_dense_7_loss: 0.1073 - val_loss: 0.5241
# Epoch 24/3000
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 12s 1s/step - dense_5_loss: 0.4203 - dense_7_loss: 0.1368 - loss: 0.5572 - val_dense_5_loss: 0.3943 - val_dense_7_loss: 0.0956 - val_loss: 0.5065
# Epoch 25/3000
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 13s 1s/step - dense_5_loss: 0.4145 - dense_7_loss: 0.1294 - loss: 0.5439 - val_dense_5_loss: 0.3850 - val_dense_7_loss: 0.0916 - val_loss: 0.4909
# Epoch 26/3000
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 13s 1s/step - dense_5_loss: 0.4094 - dense_7_loss: 0.1214 - loss: 0.5308 - val_dense_5_loss: 0.3773 - val_dense_7_loss: 0.0994 - val_loss: 0.4880
# Epoch 27/3000
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 13s 1s/step - dense_5_loss: 0.4001 - dense_7_loss: 0.1242 - loss: 0.5243 - val_dense_5_loss: 0.3676 - val_dense_7_loss: 0.0859 - val_loss: 0.4691
# Epoch 28/3000
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 12s 1s/step - dense_5_loss: 0.3955 - dense_7_loss: 0.1092 - loss: 0.5046 - val_dense_5_loss: 0.3616 - val_dense_7_loss: 0.0847 - val_loss: 0.4604
# Epoch 29/3000
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 13s 1s/step - dense_5_loss: 0.3837 - dense_7_loss: 0.1150 - loss: 0.4987 - val_dense_5_loss: 0.3629 - val_dense_7_loss: 0.0913 - val_loss: 0.4642
# Epoch 30/3000
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 13s 1s/step - dense_5_loss: 0.3812 - dense_7_loss: 0.1078 - loss: 0.4890 - val_dense_5_loss: 0.3516 - val_dense_7_loss: 0.0830 - val_loss: 0.4510
# Epoch 31/3000
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 13s 1s/step - dense_5_loss: 0.3795 - dense_7_loss: 0.1069 - loss: 0.4864 - val_dense_5_loss: 0.3457 - val_dense_7_loss: 0.0779 - val_loss: 0.4363
# Epoch 32/3000
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 12s 1s/step - dense_5_loss: 0.3803 - dense_7_loss: 0.1089 - loss: 0.4892 - val_dense_5_loss: 0.3447 - val_dense_7_loss: 0.0765 - val_loss: 0.4341
# Epoch 33/3000
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 12s 1s/step - dense_5_loss: 0.3687 - dense_7_loss: 0.1027 - loss: 0.4714 - val_dense_5_loss: 0.3402 - val_dense_7_loss: 0.0743 - val_loss: 0.4274
# Epoch 34/3000
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 12s 1s/step - dense_5_loss: 0.3661 - dense_7_loss: 0.0986 - loss: 0.4647 - val_dense_5_loss: 0.3395 - val_dense_7_loss: 0.0725 - val_loss: 0.4235
# Epoch 35/3000
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 12s 1s/step - dense_5_loss: 0.3628 - dense_7_loss: 0.0984 - loss: 0.4612 - val_dense_5_loss: 0.3365 - val_dense_7_loss: 0.0707 - val_loss: 0.4195
# Epoch 36/3000
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 12s 1s/step - dense_5_loss: 0.3570 - dense_7_loss: 0.0917 - loss: 0.4487 - val_dense_5_loss: 0.3416 - val_dense_7_loss: 0.0737 - val_loss: 0.4243
# Epoch 37/3000
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 13s 1s/step - dense_5_loss: 0.3585 - dense_7_loss: 0.0962 - loss: 0.4547 - val_dense_5_loss: 0.3316 - val_dense_7_loss: 0.0702 - val_loss: 0.4149
# Epoch 38/3000
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 12s 1s/step - dense_5_loss: 0.3590 - dense_7_loss: 0.0927 - loss: 0.4517 - val_dense_5_loss: 0.3287 - val_dense_7_loss: 0.0670 - val_loss: 0.4072
# Epoch 39/3000
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 12s 1s/step - dense_5_loss: 0.3509 - dense_7_loss: 0.0959 - loss: 0.4468 - val_dense_5_loss: 0.3325 - val_dense_7_loss: 0.0787 - val_loss: 0.4270
# Epoch 40/3000
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 12s 1s/step - dense_5_loss: 0.3544 - dense_7_loss: 0.1022 - loss: 0.4567 - val_dense_5_loss: 0.3330 - val_dense_7_loss: 0.0773 - val_loss: 0.4182
# Epoch 41/3000
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 12s 1s/step - dense_5_loss: 0.3519 - dense_7_loss: 0.0900 - loss: 0.4419 - val_dense_5_loss: 0.3219 - val_dense_7_loss: 0.0658 - val_loss: 0.3999
# Epoch 42/3000
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 12s 1s/step - dense_5_loss: 0.3489 - dense_7_loss: 0.0904 - loss: 0.4394 - val_dense_5_loss: 0.3223 - val_dense_7_loss: 0.0637 - val_loss: 0.3986
# Epoch 43/3000
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 12s 1s/step - dense_5_loss: 0.3506 - dense_7_loss: 0.0924 - loss: 0.4430 - val_dense_5_loss: 0.3247 - val_dense_7_loss: 0.0693 - val_loss: 0.4016
# Epoch 44/3000
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 12s 1s/step - dense_5_loss: 0.3447 - dense_7_loss: 0.0900 - loss: 0.4347 - val_dense_5_loss: 0.3187 - val_dense_7_loss: 0.0619 - val_loss: 0.3911
# Epoch 45/3000
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 12s 1s/step - dense_5_loss: 0.3444 - dense_7_loss: 0.0843 - loss: 0.4287 - val_dense_5_loss: 0.3259 - val_dense_7_loss: 0.0747 - val_loss: 0.4164
# Epoch 46/3000
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 12s 1s/step - dense_5_loss: 0.3460 - dense_7_loss: 0.0944 - loss: 0.4403 - val_dense_5_loss: 0.3398 - val_dense_7_loss: 0.0790 - val_loss: 0.4240
# Epoch 47/3000
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 12s 1s/step - dense_5_loss: 0.3471 - dense_7_loss: 0.0913 - loss: 0.4384 - val_dense_5_loss: 0.3174 - val_dense_7_loss: 0.0719 - val_loss: 0.4038
# Epoch 48/3000
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 12s 1s/step - dense_5_loss: 0.3385 - dense_7_loss: 0.0849 - loss: 0.4234 - val_dense_5_loss: 0.3118 - val_dense_7_loss: 0.0586 - val_loss: 0.3803
# Epoch 49/3000
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 12s 1s/step - dense_5_loss: 0.3352 - dense_7_loss: 0.0841 - loss: 0.4193 - val_dense_5_loss: 0.3174 - val_dense_7_loss: 0.0670 - val_loss: 0.3902
# Epoch 50/3000
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 13s 1s/step - dense_5_loss: 0.3353 - dense_7_loss: 0.0849 - loss: 0.4202 - val_dense_5_loss: 0.3139 - val_dense_7_loss: 0.0573 - val_loss: 0.3797
# Epoch 51/3000
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 15s 1s/step - dense_5_loss: 0.3336 - dense_7_loss: 0.0782 - loss: 0.4119 - val_dense_5_loss: 0.3106 - val_dense_7_loss: 0.0602 - val_loss: 0.3813
# Epoch 52/3000
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 12s 1s/step - dense_5_loss: 0.3351 - dense_7_loss: 0.0859 - loss: 0.4210 - val_dense_5_loss: 0.3100 - val_dense_7_loss: 0.0562 - val_loss: 0.3734
# Epoch 53/3000
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 12s 1s/step - dense_5_loss: 0.3314 - dense_7_loss: 0.0793 - loss: 0.4107 - val_dense_5_loss: 0.3094 - val_dense_7_loss: 0.0630 - val_loss: 0.3846
# Epoch 54/3000
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 14s 1s/step - dense_5_loss: 0.3341 - dense_7_loss: 0.0804 - loss: 0.4145 - val_dense_5_loss: 0.3097 - val_dense_7_loss: 0.0621 - val_loss: 0.3782
# Epoch 55/3000
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 13s 1s/step - dense_5_loss: 0.3339 - dense_7_loss: 0.0792 - loss: 0.4131 - val_dense_5_loss: 0.3035 - val_dense_7_loss: 0.0538 - val_loss: 0.3656
# Epoch 56/3000
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 12s 1s/step - dense_5_loss: 0.3293 - dense_7_loss: 0.0802 - loss: 0.4095 - val_dense_5_loss: 0.3063 - val_dense_7_loss: 0.0626 - val_loss: 0.3806
# Epoch 57/3000
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 13s 1s/step - dense_5_loss: 0.3336 - dense_7_loss: 0.0908 - loss: 0.4244 - val_dense_5_loss: 0.3121 - val_dense_7_loss: 0.0612 - val_loss: 0.3782
# Epoch 58/3000
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 12s 1s/step - dense_5_loss: 0.3272 - dense_7_loss: 0.0745 - loss: 0.4018 - val_dense_5_loss: 0.3068 - val_dense_7_loss: 0.0549 - val_loss: 0.3681
# Epoch 59/3000
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 12s 1s/step - dense_5_loss: 0.3261 - dense_7_loss: 0.0740 - loss: 0.4001 - val_dense_5_loss: 0.3014 - val_dense_7_loss: 0.0521 - val_loss: 0.3608
# Epoch 60/3000
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 12s 1s/step - dense_5_loss: 0.3263 - dense_7_loss: 0.0704 - loss: 0.3967 - val_dense_5_loss: 0.3017 - val_dense_7_loss: 0.0525 - val_loss: 0.3597
# Epoch 61/3000
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 12s 1s/step - dense_5_loss: 0.3234 - dense_7_loss: 0.0723 - loss: 0.3957 - val_dense_5_loss: 0.3003 - val_dense_7_loss: 0.0511 - val_loss: 0.3574
# Epoch 62/3000
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 12s 1s/step - dense_5_loss: 0.3149 - dense_7_loss: 0.0670 - loss: 0.3819 - val_dense_5_loss: 0.3009 - val_dense_7_loss: 0.0574 - val_loss: 0.3694
# Epoch 63/3000
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 13s 1s/step - dense_5_loss: 0.3194 - dense_7_loss: 0.0742 - loss: 0.3936 - val_dense_5_loss: 0.2976 - val_dense_7_loss: 0.0522 - val_loss: 0.3556
# Epoch 64/3000
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 12s 1s/step - dense_5_loss: 0.3166 - dense_7_loss: 0.0712 - loss: 0.3877 - val_dense_5_loss: 0.2978 - val_dense_7_loss: 0.0549 - val_loss: 0.3573
# Epoch 65/3000
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 12s 1s/step - dense_5_loss: 0.3190 - dense_7_loss: 0.0711 - loss: 0.3901 - val_dense_5_loss: 0.2952 - val_dense_7_loss: 0.0502 - val_loss: 0.3506
# Epoch 66/3000
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 12s 1s/step - dense_5_loss: 0.3181 - dense_7_loss: 0.0686 - loss: 0.3867 - val_dense_5_loss: 0.2939 - val_dense_7_loss: 0.0506 - val_loss: 0.3523
# Epoch 67/3000
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 14s 1s/step - dense_5_loss: 0.3132 - dense_7_loss: 0.0717 - loss: 0.3848 - val_dense_5_loss: 0.3059 - val_dense_7_loss: 0.0637 - val_loss: 0.3719
# Epoch 68/3000
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[4], line 77
#      74 # Fit the model
#      75 callback = tf.keras.callbacks.EarlyStopping(monitor='val_loss', patience=patience)
# ---> 77 history = model.fit(X_train, (y_train_1, y_train_2), epochs=n_epochs,
#      78                     batch_size=batch_size,
#      79                     verbose=1,
#      80                     validation_split=0.1,
#      81                     callbacks=[callback])
#      83 model.save("./multiTask_model_50000_extensive.keras")
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/keras/src/utils/traceback_utils.py:117, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     115 filtered_tb = None
#     116 try:
# --> 117     return fn(*args, **kwargs)
#     118 except Exception as e:
#     119     filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/keras/src/backend/tensorflow/trainer.py:320, in TensorFlowTrainer.fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq)
#     318 for step, iterator in epoch_iterator.enumerate_epoch():
#     319     callbacks.on_train_batch_begin(step)
# --> 320     logs = self.train_function(iterator)
#     321     logs = self._pythonify_logs(logs)
#     322     callbacks.on_train_batch_end(step, logs)
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/tensorflow/python/util/traceback_utils.py:150, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     148 filtered_tb = None
#     149 try:
# --> 150   return fn(*args, **kwargs)
#     151 except Exception as e:
#     152   filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/tensorflow/python/eager/polymorphic_function/polymorphic_function.py:833, in Function.__call__(self, *args, **kwds)
#     830 compiler = "xla" if self._jit_compile else "nonXla"
#     832 with OptionalXlaContext(self._jit_compile):
# --> 833   result = self._call(*args, **kwds)
#     835 new_tracing_count = self.experimental_get_tracing_count()
#     836 without_tracing = (tracing_count == new_tracing_count)
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/tensorflow/python/eager/polymorphic_function/polymorphic_function.py:878, in Function._call(self, *args, **kwds)
#     875 self._lock.release()
#     876 # In this case we have not created variables on the first call. So we can
#     877 # run the first trace but we should fail if variables are created.
# --> 878 results = tracing_compilation.call_function(
#     879     args, kwds, self._variable_creation_config
#     880 )
#     881 if self._created_variables:
#     882   raise ValueError("Creating variables on a non-first call to a function"
#     883                    " decorated with tf.function.")
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/tensorflow/python/eager/polymorphic_function/tracing_compilation.py:139, in call_function(args, kwargs, tracing_options)
#     137 bound_args = function.function_type.bind(*args, **kwargs)
#     138 flat_inputs = function.function_type.unpack_inputs(bound_args)
# --> 139 return function._call_flat(  # pylint: disable=protected-access
#     140     flat_inputs, captured_inputs=function.captured_inputs
#     141 )
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/tensorflow/python/eager/polymorphic_function/concrete_function.py:1322, in ConcreteFunction._call_flat(self, tensor_inputs, captured_inputs)
#    1318 possible_gradient_type = gradients_util.PossibleTapeGradientTypes(args)
#    1319 if (possible_gradient_type == gradients_util.POSSIBLE_GRADIENT_TYPES_NONE
#    1320     and executing_eagerly):
#    1321   # No tape is watching; skip to running the function.
# -> 1322   return self._inference_function.call_preflattened(args)
#    1323 forward_backward = self._select_forward_and_backward_functions(
#    1324     args,
#    1325     possible_gradient_type,
#    1326     executing_eagerly)
#    1327 forward_function, args_with_tangents = forward_backward.forward()
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/tensorflow/python/eager/polymorphic_function/atomic_function.py:216, in AtomicFunction.call_preflattened(self, args)
#     214 def call_preflattened(self, args: Sequence[core.Tensor]) -> Any:
#     215   """Calls with flattened tensor inputs and returns the structured output."""
# --> 216   flat_outputs = self.call_flat(*args)
#     217   return self.function_type.pack_output(flat_outputs)
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/tensorflow/python/eager/polymorphic_function/atomic_function.py:251, in AtomicFunction.call_flat(self, *args)
#     249 with record.stop_recording():
#     250   if self._bound_context.executing_eagerly():
# --> 251     outputs = self._bound_context.call_function(
#     252         self.name,
#     253         list(args),
#     254         len(self.function_type.flat_outputs),
#     255     )
#     256   else:
#     257     outputs = make_call_op_in_graph(
#     258         self,
#     259         list(args),
#     260         self._bound_context.function_call_options.as_attrs(),
#     261     )
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/tensorflow/python/eager/context.py:1552, in Context.call_function(self, name, tensor_inputs, num_outputs)
#    1550 cancellation_context = cancellation.context()
#    1551 if cancellation_context is None:
# -> 1552   outputs = execute.execute(
#    1553       name.decode("utf-8"),
#    1554       num_outputs=num_outputs,
#    1555       inputs=tensor_inputs,
#    1556       attrs=attrs,
#    1557       ctx=self,
#    1558   )
#    1559 else:
#    1560   outputs = execute.execute_with_cancellation(
#    1561       name.decode("utf-8"),
#    1562       num_outputs=num_outputs,
#    (...)
#    1566       cancellation_manager=cancellation_context,
#    1567   )
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/tensorflow/python/eager/execute.py:53, in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      51 try:
#      52   ctx.ensure_initialized()
# ---> 53   tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
#      54                                       inputs, attrs, num_outputs)
#      55 except core._NotOkStatusException as e:
#      56   if name is not None:
#
# KeyboardInterrupt:
